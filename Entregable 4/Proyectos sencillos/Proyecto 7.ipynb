# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        36928
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         73856
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 128)         147584
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 500)               1024500
#
#  dropout_3 (Dropout)         (None, 500)               0
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 1510278 (5.76 MB)
# Trainable params: 1510278 (5.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 14s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_acc = EarlyStopping(monitor='val_accuracy', patience=5)

modelchk = ModelCheckpoint('/tmp/chkpoint', monitor = 'val_accuracy',
                           verbose=1, save_best_only=True, save_weights_only=True)

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train,
                    callbacks=[modelchk, callback_loss, callback_acc],
                    epochs=300,
                    batch_size= 512,
                    validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - ETA: 0s - loss: 2.0793 - accuracy: 0.2169
# Epoch 1: val_accuracy improved from -inf to 0.32930, saving model to /tmp/chkpoint
# 79/79 [==============================] - 19s 111ms/step - loss: 2.0793 - accuracy: 0.2169 - val_loss: 1.7861 - val_accuracy: 0.3293
# Epoch 2/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.7021 - accuracy: 0.3610
# Epoch 2: val_accuracy improved from 0.32930 to 0.43250, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 83ms/step - loss: 1.7022 - accuracy: 0.3610 - val_loss: 1.5010 - val_accuracy: 0.4325
# Epoch 3/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.4945 - accuracy: 0.4464
# Epoch 3: val_accuracy improved from 0.43250 to 0.49540, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 85ms/step - loss: 1.4942 - accuracy: 0.4465 - val_loss: 1.3734 - val_accuracy: 0.4954
# Epoch 4/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.3558 - accuracy: 0.5009
# Epoch 4: val_accuracy improved from 0.49540 to 0.52180, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 85ms/step - loss: 1.3558 - accuracy: 0.5009 - val_loss: 1.2913 - val_accuracy: 0.5218
# Epoch 5/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.2507 - accuracy: 0.5471
# Epoch 5: val_accuracy improved from 0.52180 to 0.59390, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 1.2503 - accuracy: 0.5473 - val_loss: 1.1197 - val_accuracy: 0.5939
# Epoch 6/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.1432 - accuracy: 0.5892
# Epoch 6: val_accuracy improved from 0.59390 to 0.62750, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 1.1429 - accuracy: 0.5893 - val_loss: 1.0279 - val_accuracy: 0.6275
# Epoch 7/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.0567 - accuracy: 0.6217
# Epoch 7: val_accuracy improved from 0.62750 to 0.63030, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 1.0566 - accuracy: 0.6218 - val_loss: 1.0438 - val_accuracy: 0.6303
# Epoch 8/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9702 - accuracy: 0.6547
# Epoch 8: val_accuracy improved from 0.63030 to 0.65030, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 91ms/step - loss: 0.9703 - accuracy: 0.6547 - val_loss: 0.9845 - val_accuracy: 0.6503
# Epoch 9/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9304 - accuracy: 0.6709
# Epoch 9: val_accuracy improved from 0.65030 to 0.67650, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 87ms/step - loss: 0.9305 - accuracy: 0.6709 - val_loss: 0.8990 - val_accuracy: 0.6765
# Epoch 10/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8581 - accuracy: 0.6945
# Epoch 10: val_accuracy improved from 0.67650 to 0.69110, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.8583 - accuracy: 0.6944 - val_loss: 0.8726 - val_accuracy: 0.6911
# Epoch 11/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8261 - accuracy: 0.7084
# Epoch 11: val_accuracy improved from 0.69110 to 0.72280, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 85ms/step - loss: 0.8263 - accuracy: 0.7083 - val_loss: 0.7804 - val_accuracy: 0.7228
# Epoch 12/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7902 - accuracy: 0.7205
# Epoch 12: val_accuracy improved from 0.72280 to 0.73160, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.7900 - accuracy: 0.7205 - val_loss: 0.7651 - val_accuracy: 0.7316
# Epoch 13/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7365 - accuracy: 0.7392
# Epoch 13: val_accuracy improved from 0.73160 to 0.74200, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 95ms/step - loss: 0.7366 - accuracy: 0.7391 - val_loss: 0.7353 - val_accuracy: 0.7420
# Epoch 14/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7046 - accuracy: 0.7511
# Epoch 14: val_accuracy improved from 0.74200 to 0.74830, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 96ms/step - loss: 0.7043 - accuracy: 0.7513 - val_loss: 0.7208 - val_accuracy: 0.7483
# Epoch 15/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6797 - accuracy: 0.7581
# Epoch 15: val_accuracy improved from 0.74830 to 0.75420, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.6794 - accuracy: 0.7583 - val_loss: 0.7026 - val_accuracy: 0.7542
# Epoch 16/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6358 - accuracy: 0.7767
# Epoch 16: val_accuracy improved from 0.75420 to 0.76610, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 85ms/step - loss: 0.6358 - accuracy: 0.7767 - val_loss: 0.6917 - val_accuracy: 0.7661
# Epoch 17/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6209 - accuracy: 0.7810
# Epoch 17: val_accuracy improved from 0.76610 to 0.77640, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.6214 - accuracy: 0.7808 - val_loss: 0.6487 - val_accuracy: 0.7764
# Epoch 18/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5999 - accuracy: 0.7895
# Epoch 18: val_accuracy did not improve from 0.77640
# 79/79 [==============================] - 7s 84ms/step - loss: 0.5999 - accuracy: 0.7895 - val_loss: 0.6735 - val_accuracy: 0.7686
# Epoch 19/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5655 - accuracy: 0.8008
# Epoch 19: val_accuracy did not improve from 0.77640
# 79/79 [==============================] - 7s 84ms/step - loss: 0.5657 - accuracy: 0.8007 - val_loss: 0.6537 - val_accuracy: 0.7734
# Epoch 20/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5427 - accuracy: 0.8077
# Epoch 20: val_accuracy did not improve from 0.77640
# 79/79 [==============================] - 7s 84ms/step - loss: 0.5425 - accuracy: 0.8078 - val_loss: 0.6487 - val_accuracy: 0.7758
# Epoch 21/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5135 - accuracy: 0.8155
# Epoch 21: val_accuracy improved from 0.77640 to 0.78550, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.5136 - accuracy: 0.8155 - val_loss: 0.6280 - val_accuracy: 0.7855
# Epoch 22/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5072 - accuracy: 0.8188
# Epoch 22: val_accuracy improved from 0.78550 to 0.80060, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.5071 - accuracy: 0.8189 - val_loss: 0.5936 - val_accuracy: 0.8006
# Epoch 23/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4778 - accuracy: 0.8301
# Epoch 23: val_accuracy improved from 0.80060 to 0.80430, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.4779 - accuracy: 0.8300 - val_loss: 0.6036 - val_accuracy: 0.8043
# Epoch 24/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4745 - accuracy: 0.8343
# Epoch 24: val_accuracy did not improve from 0.80430
# 79/79 [==============================] - 7s 84ms/step - loss: 0.4746 - accuracy: 0.8342 - val_loss: 0.6299 - val_accuracy: 0.7926
# Epoch 25/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4604 - accuracy: 0.8360
# Epoch 25: val_accuracy did not improve from 0.80430
# 79/79 [==============================] - 7s 85ms/step - loss: 0.4602 - accuracy: 0.8361 - val_loss: 0.6285 - val_accuracy: 0.7963
# Epoch 26/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4292 - accuracy: 0.8482
# Epoch 26: val_accuracy improved from 0.80430 to 0.80530, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.4294 - accuracy: 0.8481 - val_loss: 0.5872 - val_accuracy: 0.8053
# Epoch 27/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4417 - accuracy: 0.8442
# Epoch 27: val_accuracy did not improve from 0.80530
# 79/79 [==============================] - 7s 89ms/step - loss: 0.4417 - accuracy: 0.8442 - val_loss: 0.5907 - val_accuracy: 0.8040
# Epoch 28/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4052 - accuracy: 0.8534
# Epoch 28: val_accuracy did not improve from 0.80530
# 79/79 [==============================] - 7s 84ms/step - loss: 0.4053 - accuracy: 0.8534 - val_loss: 0.5949 - val_accuracy: 0.8048
# Epoch 29/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3951 - accuracy: 0.8582
# Epoch 29: val_accuracy improved from 0.80530 to 0.80570, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 85ms/step - loss: 0.3950 - accuracy: 0.8582 - val_loss: 0.6068 - val_accuracy: 0.8057
# Epoch 30/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3863 - accuracy: 0.8640
# Epoch 30: val_accuracy did not improve from 0.80570
# 79/79 [==============================] - 7s 84ms/step - loss: 0.3861 - accuracy: 0.8640 - val_loss: 0.6099 - val_accuracy: 0.8051
# Epoch 31/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3831 - accuracy: 0.8628
# Epoch 31: val_accuracy improved from 0.80570 to 0.80870, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 85ms/step - loss: 0.3831 - accuracy: 0.8629 - val_loss: 0.5815 - val_accuracy: 0.8087
# Epoch 32/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3605 - accuracy: 0.8724
# Epoch 32: val_accuracy improved from 0.80870 to 0.81420, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.3606 - accuracy: 0.8724 - val_loss: 0.5671 - val_accuracy: 0.8142
# Epoch 33/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3472 - accuracy: 0.8754
# Epoch 33: val_accuracy did not improve from 0.81420
# 79/79 [==============================] - 7s 84ms/step - loss: 0.3472 - accuracy: 0.8755 - val_loss: 0.5953 - val_accuracy: 0.8119
# Epoch 34/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3460 - accuracy: 0.8755
# Epoch 34: val_accuracy did not improve from 0.81420
# 79/79 [==============================] - 7s 84ms/step - loss: 0.3458 - accuracy: 0.8755 - val_loss: 0.6076 - val_accuracy: 0.8120
# Epoch 35/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3305 - accuracy: 0.8825
# Epoch 35: val_accuracy did not improve from 0.81420
# 79/79 [==============================] - 7s 85ms/step - loss: 0.3308 - accuracy: 0.8824 - val_loss: 0.5975 - val_accuracy: 0.8127
# Epoch 36/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3265 - accuracy: 0.8822
# Epoch 36: val_accuracy did not improve from 0.81420
# 79/79 [==============================] - 7s 84ms/step - loss: 0.3267 - accuracy: 0.8821 - val_loss: 0.6173 - val_accuracy: 0.8093
# Epoch 37/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3263 - accuracy: 0.8818
# Epoch 37: val_accuracy did not improve from 0.81420
# 79/79 [==============================] - 7s 85ms/step - loss: 0.3261 - accuracy: 0.8819 - val_loss: 0.6024 - val_accuracy: 0.8142

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:04:24.675445

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 80.380

# %%
model.load_weights('/tmp/chkpoint')

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/M7. Deep Learning/Entregable 4/" # A revisar en vuestra instancia

# model.save(ruta_googledrive+'cifar10_base_model.h5')
