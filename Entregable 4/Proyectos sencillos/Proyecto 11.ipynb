# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# # Aquí iria el codigo para conectarse a Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
# prueba 2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization

model = Sequential()
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(256, (3, 3), strides=1, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(256, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 32, 32, 64)        1792
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 64)        36928
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 64)        36928
#
#  max_pooling2d_6 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_21 (Conv2D)          (None, 16, 16, 128)       73856
#
#  conv2d_22 (Conv2D)          (None, 16, 16, 128)       147584
#
#  conv2d_23 (Conv2D)          (None, 16, 16, 128)       147584
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_24 (Conv2D)          (None, 8, 8, 256)         295168
#
#  batch_normalization_3 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  conv2d_25 (Conv2D)          (None, 8, 8, 256)         590080
#
#  conv2d_26 (Conv2D)          (None, 8, 8, 256)         590080
#
#  max_pooling2d_8 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 4, 4, 256)         0
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 1024)              4195328
#
#  dropout_11 (Dropout)        (None, 1024)              0
#
#  dense_5 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 6126602 (23.37 MB)
# Trainable params: 6126090 (23.37 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_acc = EarlyStopping(monitor='val_accuracy', patience=5)

modelchk = ModelCheckpoint('/tmp/chkpoint', monitor = 'val_accuracy',
                           verbose=1, save_best_only=True, save_weights_only=True)

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train,
                    callbacks=[modelchk, callback_loss, callback_acc],
                    epochs=300,
                    batch_size= 512,
                    validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.9830 - accuracy: 0.2508
# Epoch 1: val_accuracy improved from -inf to 0.12990, saving model to /tmp/chkpoint
# 79/79 [==============================] - 20s 202ms/step - loss: 1.9824 - accuracy: 0.2510 - val_loss: 2.2424 - val_accuracy: 0.1299
# Epoch 2/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.5215 - accuracy: 0.4359
# Epoch 2: val_accuracy improved from 0.12990 to 0.36280, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 184ms/step - loss: 1.5213 - accuracy: 0.4361 - val_loss: 2.1286 - val_accuracy: 0.3628
# Epoch 3/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.2657 - accuracy: 0.5389
# Epoch 3: val_accuracy did not improve from 0.36280
# 79/79 [==============================] - 15s 188ms/step - loss: 1.2652 - accuracy: 0.5391 - val_loss: 2.0218 - val_accuracy: 0.3320
# Epoch 4/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.0816 - accuracy: 0.6124
# Epoch 4: val_accuracy improved from 0.36280 to 0.42330, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 184ms/step - loss: 1.0816 - accuracy: 0.6125 - val_loss: 1.8809 - val_accuracy: 0.4233
# Epoch 5/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9603 - accuracy: 0.6574
# Epoch 5: val_accuracy improved from 0.42330 to 0.56320, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 189ms/step - loss: 0.9604 - accuracy: 0.6574 - val_loss: 1.5687 - val_accuracy: 0.5632
# Epoch 6/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8622 - accuracy: 0.6956
# Epoch 6: val_accuracy improved from 0.56320 to 0.69780, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 182ms/step - loss: 0.8624 - accuracy: 0.6955 - val_loss: 1.1887 - val_accuracy: 0.6978
# Epoch 7/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7965 - accuracy: 0.7183
# Epoch 7: val_accuracy did not improve from 0.69780
# 79/79 [==============================] - 15s 187ms/step - loss: 0.7966 - accuracy: 0.7182 - val_loss: 1.1027 - val_accuracy: 0.6194
# Epoch 8/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7320 - accuracy: 0.7419
# Epoch 8: val_accuracy improved from 0.69780 to 0.74590, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 189ms/step - loss: 0.7317 - accuracy: 0.7420 - val_loss: 0.7682 - val_accuracy: 0.7459
# Epoch 9/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6790 - accuracy: 0.7597
# Epoch 9: val_accuracy improved from 0.74590 to 0.75450, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 190ms/step - loss: 0.6790 - accuracy: 0.7596 - val_loss: 0.7111 - val_accuracy: 0.7545
# Epoch 10/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6365 - accuracy: 0.7757
# Epoch 10: val_accuracy did not improve from 0.75450
# 79/79 [==============================] - 14s 180ms/step - loss: 0.6366 - accuracy: 0.7756 - val_loss: 0.8213 - val_accuracy: 0.7196
# Epoch 11/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6019 - accuracy: 0.7908
# Epoch 11: val_accuracy improved from 0.75450 to 0.77420, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 182ms/step - loss: 0.6020 - accuracy: 0.7907 - val_loss: 0.6543 - val_accuracy: 0.7742
# Epoch 12/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5674 - accuracy: 0.7998
# Epoch 12: val_accuracy improved from 0.77420 to 0.77790, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 188ms/step - loss: 0.5675 - accuracy: 0.7997 - val_loss: 0.6698 - val_accuracy: 0.7779
# Epoch 13/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5289 - accuracy: 0.8128
# Epoch 13: val_accuracy improved from 0.77790 to 0.79370, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 182ms/step - loss: 0.5289 - accuracy: 0.8129 - val_loss: 0.6290 - val_accuracy: 0.7937
# Epoch 14/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5078 - accuracy: 0.8232
# Epoch 14: val_accuracy did not improve from 0.79370
# 79/79 [==============================] - 14s 180ms/step - loss: 0.5080 - accuracy: 0.8232 - val_loss: 0.6461 - val_accuracy: 0.7865
# Epoch 15/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4732 - accuracy: 0.8316
# Epoch 15: val_accuracy did not improve from 0.79370
# 79/79 [==============================] - 14s 179ms/step - loss: 0.4733 - accuracy: 0.8316 - val_loss: 0.7656 - val_accuracy: 0.7673
# Epoch 16/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4505 - accuracy: 0.8440
# Epoch 16: val_accuracy improved from 0.79370 to 0.81010, saving model to /tmp/chkpoint
# 79/79 [==============================] - 16s 205ms/step - loss: 0.4507 - accuracy: 0.8439 - val_loss: 0.5798 - val_accuracy: 0.8101
# Epoch 17/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4271 - accuracy: 0.8499
# Epoch 17: val_accuracy did not improve from 0.81010
# 79/79 [==============================] - 14s 179ms/step - loss: 0.4272 - accuracy: 0.8499 - val_loss: 0.6193 - val_accuracy: 0.7931
# Epoch 18/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4004 - accuracy: 0.8576
# Epoch 18: val_accuracy did not improve from 0.81010
# 79/79 [==============================] - 14s 179ms/step - loss: 0.4003 - accuracy: 0.8575 - val_loss: 0.6127 - val_accuracy: 0.8028
# Epoch 19/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3806 - accuracy: 0.8645
# Epoch 19: val_accuracy improved from 0.81010 to 0.81570, saving model to /tmp/chkpoint
# 79/79 [==============================] - 16s 208ms/step - loss: 0.3805 - accuracy: 0.8645 - val_loss: 0.5520 - val_accuracy: 0.8157
# Epoch 20/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3632 - accuracy: 0.8724
# Epoch 20: val_accuracy improved from 0.81570 to 0.81880, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 182ms/step - loss: 0.3632 - accuracy: 0.8724 - val_loss: 0.5678 - val_accuracy: 0.8188
# Epoch 21/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3512 - accuracy: 0.8737
# Epoch 21: val_accuracy did not improve from 0.81880
# 79/79 [==============================] - 15s 186ms/step - loss: 0.3511 - accuracy: 0.8738 - val_loss: 0.7061 - val_accuracy: 0.7917
# Epoch 22/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3305 - accuracy: 0.8812
# Epoch 22: val_accuracy did not improve from 0.81880
# 79/79 [==============================] - 14s 179ms/step - loss: 0.3304 - accuracy: 0.8812 - val_loss: 0.5931 - val_accuracy: 0.8176
# Epoch 23/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3092 - accuracy: 0.8898
# Epoch 23: val_accuracy did not improve from 0.81880
# 79/79 [==============================] - 15s 186ms/step - loss: 0.3093 - accuracy: 0.8897 - val_loss: 0.6022 - val_accuracy: 0.8137
# Epoch 24/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3013 - accuracy: 0.8948
# Epoch 24: val_accuracy did not improve from 0.81880
# 79/79 [==============================] - 14s 180ms/step - loss: 0.3011 - accuracy: 0.8949 - val_loss: 0.6320 - val_accuracy: 0.8104

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:05:59.350905

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 80.700

# %%
model.load_weights('/tmp/chkpoint')

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/M7. Deep Learning/Entregable 4/" # A revisar en vuestra instancia

# model.save(ruta_googledrive+'cifar10_base_model.h5')
