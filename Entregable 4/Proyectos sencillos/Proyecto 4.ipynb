# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# # Aquí iria el codigo para conectarse a Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

# Primera capa de convolución
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))


# Segunda capa de convolución
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))


# Tercera capa de convolución
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))


model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        36928
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         73856
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 128)         147584
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 500)               1024500
#
#  dropout (Dropout)           (None, 500)               0
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 1510278 (5.76 MB)
# Trainable params: 1510278 (5.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_acc = EarlyStopping(monitor='val_accuracy', patience=5)

modelchk = ModelCheckpoint('/tmp/chkpoint', monitor = 'val_accuracy',
                           verbose=1, save_best_only=True, save_weights_only=True)

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train,
                    callbacks=[modelchk, callback_loss, callback_acc],
                    epochs=300,
                    batch_size= 512,
                    validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - ETA: 0s - loss: 2.0357 - accuracy: 0.2389
# Epoch 1: val_accuracy improved from -inf to 0.34710, saving model to /tmp/chkpoint
# 79/79 [==============================] - 16s 91ms/step - loss: 2.0357 - accuracy: 0.2389 - val_loss: 1.7512 - val_accuracy: 0.3471
# Epoch 2/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.6489 - accuracy: 0.3875
# Epoch 2: val_accuracy improved from 0.34710 to 0.45810, saving model to /tmp/chkpoint
# 79/79 [==============================] - 6s 73ms/step - loss: 1.6489 - accuracy: 0.3874 - val_loss: 1.4780 - val_accuracy: 0.4581
# Epoch 3/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.4208 - accuracy: 0.4829
# Epoch 3: val_accuracy improved from 0.45810 to 0.52250, saving model to /tmp/chkpoint
# 79/79 [==============================] - 5s 69ms/step - loss: 1.4207 - accuracy: 0.4830 - val_loss: 1.3134 - val_accuracy: 0.5225
# Epoch 4/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.2617 - accuracy: 0.5449
# Epoch 4: val_accuracy improved from 0.52250 to 0.57940, saving model to /tmp/chkpoint
# 79/79 [==============================] - 6s 75ms/step - loss: 1.2618 - accuracy: 0.5448 - val_loss: 1.1644 - val_accuracy: 0.5794
# Epoch 5/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.1136 - accuracy: 0.6007
# Epoch 5: val_accuracy improved from 0.57940 to 0.61720, saving model to /tmp/chkpoint
# 79/79 [==============================] - 6s 71ms/step - loss: 1.1136 - accuracy: 0.6006 - val_loss: 1.0605 - val_accuracy: 0.6172
# Epoch 6/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.0059 - accuracy: 0.6415
# Epoch 6: val_accuracy improved from 0.61720 to 0.65950, saving model to /tmp/chkpoint
# 79/79 [==============================] - 6s 77ms/step - loss: 1.0054 - accuracy: 0.6416 - val_loss: 0.9760 - val_accuracy: 0.6595
# Epoch 7/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9152 - accuracy: 0.6759
# Epoch 7: val_accuracy improved from 0.65950 to 0.66530, saving model to /tmp/chkpoint
# 79/79 [==============================] - 6s 71ms/step - loss: 0.9149 - accuracy: 0.6759 - val_loss: 0.9358 - val_accuracy: 0.6653
# Epoch 8/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8393 - accuracy: 0.7026
# Epoch 8: val_accuracy improved from 0.66530 to 0.69900, saving model to /tmp/chkpoint
# 79/79 [==============================] - 5s 70ms/step - loss: 0.8393 - accuracy: 0.7026 - val_loss: 0.8631 - val_accuracy: 0.6990
# Epoch 9/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7558 - accuracy: 0.7348
# Epoch 9: val_accuracy improved from 0.69900 to 0.70710, saving model to /tmp/chkpoint
# 79/79 [==============================] - 6s 70ms/step - loss: 0.7560 - accuracy: 0.7348 - val_loss: 0.8300 - val_accuracy: 0.7071
# Epoch 10/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7097 - accuracy: 0.7504
# Epoch 10: val_accuracy improved from 0.70710 to 0.72940, saving model to /tmp/chkpoint
# 79/79 [==============================] - 6s 76ms/step - loss: 0.7097 - accuracy: 0.7505 - val_loss: 0.7799 - val_accuracy: 0.7294
# Epoch 11/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6398 - accuracy: 0.7724
# Epoch 11: val_accuracy did not improve from 0.72940
# 79/79 [==============================] - 6s 71ms/step - loss: 0.6394 - accuracy: 0.7725 - val_loss: 0.8330 - val_accuracy: 0.7210
# Epoch 12/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5848 - accuracy: 0.7941
# Epoch 12: val_accuracy improved from 0.72940 to 0.73940, saving model to /tmp/chkpoint
# 79/79 [==============================] - 5s 67ms/step - loss: 0.5850 - accuracy: 0.7940 - val_loss: 0.7567 - val_accuracy: 0.7394
# Epoch 13/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5577 - accuracy: 0.8041
# Epoch 13: val_accuracy improved from 0.73940 to 0.75070, saving model to /tmp/chkpoint
# 79/79 [==============================] - 5s 69ms/step - loss: 0.5576 - accuracy: 0.8042 - val_loss: 0.7356 - val_accuracy: 0.7507
# Epoch 14/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5038 - accuracy: 0.8219
# Epoch 14: val_accuracy did not improve from 0.75070
# 79/79 [==============================] - 5s 66ms/step - loss: 0.5038 - accuracy: 0.8219 - val_loss: 0.7521 - val_accuracy: 0.7483
# Epoch 15/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4572 - accuracy: 0.8382
# Epoch 15: val_accuracy did not improve from 0.75070
# 79/79 [==============================] - 6s 71ms/step - loss: 0.4570 - accuracy: 0.8383 - val_loss: 0.8404 - val_accuracy: 0.7344
# Epoch 16/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4136 - accuracy: 0.8524
# Epoch 16: val_accuracy improved from 0.75070 to 0.76450, saving model to /tmp/chkpoint
# 79/79 [==============================] - 5s 68ms/step - loss: 0.4136 - accuracy: 0.8523 - val_loss: 0.7410 - val_accuracy: 0.7645
# Epoch 17/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3732 - accuracy: 0.8690
# Epoch 17: val_accuracy improved from 0.76450 to 0.77010, saving model to /tmp/chkpoint
# 79/79 [==============================] - 6s 75ms/step - loss: 0.3738 - accuracy: 0.8688 - val_loss: 0.7186 - val_accuracy: 0.7701
# Epoch 18/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3540 - accuracy: 0.8723
# Epoch 18: val_accuracy improved from 0.77010 to 0.77090, saving model to /tmp/chkpoint
# 79/79 [==============================] - 5s 69ms/step - loss: 0.3538 - accuracy: 0.8724 - val_loss: 0.7862 - val_accuracy: 0.7709
# Epoch 19/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3031 - accuracy: 0.8918
# Epoch 19: val_accuracy did not improve from 0.77090
# 79/79 [==============================] - 5s 67ms/step - loss: 0.3030 - accuracy: 0.8918 - val_loss: 0.8946 - val_accuracy: 0.7483
# Epoch 20/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.2755 - accuracy: 0.8991
# Epoch 20: val_accuracy did not improve from 0.77090
# 79/79 [==============================] - 5s 68ms/step - loss: 0.2755 - accuracy: 0.8991 - val_loss: 0.9075 - val_accuracy: 0.7546
# Epoch 21/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.2491 - accuracy: 0.9094
# Epoch 21: val_accuracy did not improve from 0.77090
# 79/79 [==============================] - 6s 72ms/step - loss: 0.2493 - accuracy: 0.9093 - val_loss: 0.8345 - val_accuracy: 0.7663
# Epoch 22/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.2286 - accuracy: 0.9181
# Epoch 22: val_accuracy did not improve from 0.77090
# 79/79 [==============================] - 6s 72ms/step - loss: 0.2284 - accuracy: 0.9182 - val_loss: 0.9102 - val_accuracy: 0.7695

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:02:19.602977

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 76.470

# %%
model.load_weights('/tmp/chkpoint')

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/M7. Deep Learning/Entregable 4/" # A revisar en vuestra instancia

# model.save(ruta_googledrive+'cifar10_base_model.h5')
