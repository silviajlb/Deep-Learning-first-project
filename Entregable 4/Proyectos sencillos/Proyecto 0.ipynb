# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu',
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(32, activation='relu'))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 32)                262176
#
#  dense_1 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 263402 (1.00 MB)
# Trainable params: 263402 (1.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_acc = EarlyStopping(monitor='val_accuracy', patience=5)

modelchk = ModelCheckpoint('/tmp/chkpoint', monitor = 'val_accuracy',
                           verbose=1, save_best_only=True, save_weights_only=True)

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train,
                    callbacks=[modelchk, callback_loss, callback_acc],
                    epochs=300,
                    batch_size= 512,
                    validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - ETA: 0s - loss: 2.0168 - accuracy: 0.2751
# Epoch 1: val_accuracy improved from -inf to 0.32340, saving model to /tmp/chkpoint
# 79/79 [==============================] - 5s 21ms/step - loss: 2.0168 - accuracy: 0.2751 - val_loss: 1.8768 - val_accuracy: 0.3234
# Epoch 2/300
# 77/79 [============================>.] - ETA: 0s - loss: 1.7630 - accuracy: 0.3717
# Epoch 2: val_accuracy improved from 0.32340 to 0.39390, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 11ms/step - loss: 1.7614 - accuracy: 0.3723 - val_loss: 1.7022 - val_accuracy: 0.3939
# Epoch 3/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.6217 - accuracy: 0.4227
# Epoch 3: val_accuracy improved from 0.39390 to 0.44150, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 1.6215 - accuracy: 0.4229 - val_loss: 1.5715 - val_accuracy: 0.4415
# Epoch 4/300
# 75/79 [===========================>..] - ETA: 0s - loss: 1.5227 - accuracy: 0.4544
# Epoch 4: val_accuracy improved from 0.44150 to 0.47960, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5184 - accuracy: 0.4561 - val_loss: 1.4878 - val_accuracy: 0.4796
# Epoch 5/300
# 74/79 [===========================>..] - ETA: 0s - loss: 1.4390 - accuracy: 0.4857
# Epoch 5: val_accuracy improved from 0.47960 to 0.49270, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4392 - accuracy: 0.4857 - val_loss: 1.4352 - val_accuracy: 0.4927
# Epoch 6/300
# 79/79 [==============================] - ETA: 0s - loss: 1.3869 - accuracy: 0.5046
# Epoch 6: val_accuracy improved from 0.49270 to 0.50560, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3869 - accuracy: 0.5046 - val_loss: 1.4027 - val_accuracy: 0.5056
# Epoch 7/300
# 76/79 [===========================>..] - ETA: 0s - loss: 1.3544 - accuracy: 0.5162
# Epoch 7: val_accuracy improved from 0.50560 to 0.52210, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3543 - accuracy: 0.5163 - val_loss: 1.3679 - val_accuracy: 0.5221
# Epoch 8/300
# 79/79 [==============================] - ETA: 0s - loss: 1.3296 - accuracy: 0.5249
# Epoch 8: val_accuracy did not improve from 0.52210
# 79/79 [==============================] - 1s 12ms/step - loss: 1.3296 - accuracy: 0.5249 - val_loss: 1.3887 - val_accuracy: 0.5029
# Epoch 9/300
# 73/79 [==========================>...] - ETA: 0s - loss: 1.3121 - accuracy: 0.5291
# Epoch 9: val_accuracy improved from 0.52210 to 0.52690, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 13ms/step - loss: 1.3089 - accuracy: 0.5307 - val_loss: 1.3467 - val_accuracy: 0.5269
# Epoch 10/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.2865 - accuracy: 0.5396
# Epoch 10: val_accuracy did not improve from 0.52690
# 79/79 [==============================] - 1s 13ms/step - loss: 1.2866 - accuracy: 0.5395 - val_loss: 1.3396 - val_accuracy: 0.5221
# Epoch 11/300
# 75/79 [===========================>..] - ETA: 0s - loss: 1.2770 - accuracy: 0.5406
# Epoch 11: val_accuracy improved from 0.52690 to 0.53150, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 1.2739 - accuracy: 0.5419 - val_loss: 1.3349 - val_accuracy: 0.5315
# Epoch 12/300
# 73/79 [==========================>...] - ETA: 0s - loss: 1.2497 - accuracy: 0.5510
# Epoch 12: val_accuracy improved from 0.53150 to 0.53990, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 1.2521 - accuracy: 0.5507 - val_loss: 1.3055 - val_accuracy: 0.5399
# Epoch 13/300
# 77/79 [============================>.] - ETA: 0s - loss: 1.2362 - accuracy: 0.5567
# Epoch 13: val_accuracy improved from 0.53990 to 0.54580, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 1.2361 - accuracy: 0.5565 - val_loss: 1.2878 - val_accuracy: 0.5458
# Epoch 14/300
# 74/79 [===========================>..] - ETA: 0s - loss: 1.2136 - accuracy: 0.5670
# Epoch 14: val_accuracy improved from 0.54580 to 0.54930, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 1.2143 - accuracy: 0.5667 - val_loss: 1.2837 - val_accuracy: 0.5493
# Epoch 15/300
# 77/79 [============================>.] - ETA: 0s - loss: 1.1981 - accuracy: 0.5728
# Epoch 15: val_accuracy improved from 0.54930 to 0.56130, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 1.1984 - accuracy: 0.5724 - val_loss: 1.2631 - val_accuracy: 0.5613
# Epoch 16/300
# 74/79 [===========================>..] - ETA: 0s - loss: 1.1722 - accuracy: 0.5853
# Epoch 16: val_accuracy did not improve from 0.56130
# 79/79 [==============================] - 1s 11ms/step - loss: 1.1727 - accuracy: 0.5853 - val_loss: 1.2637 - val_accuracy: 0.5578
# Epoch 17/300
# 74/79 [===========================>..] - ETA: 0s - loss: 1.1621 - accuracy: 0.5903
# Epoch 17: val_accuracy improved from 0.56130 to 0.56430, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 1.1622 - accuracy: 0.5903 - val_loss: 1.2366 - val_accuracy: 0.5643
# Epoch 18/300
# 74/79 [===========================>..] - ETA: 0s - loss: 1.1459 - accuracy: 0.5928
# Epoch 18: val_accuracy improved from 0.56430 to 0.56650, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 11ms/step - loss: 1.1456 - accuracy: 0.5930 - val_loss: 1.2370 - val_accuracy: 0.5665
# Epoch 19/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.1328 - accuracy: 0.5995
# Epoch 19: val_accuracy did not improve from 0.56650
# 79/79 [==============================] - 1s 10ms/step - loss: 1.1328 - accuracy: 0.5996 - val_loss: 1.2509 - val_accuracy: 0.5607
# Epoch 20/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.1204 - accuracy: 0.6017
# Epoch 20: val_accuracy did not improve from 0.56650
# 79/79 [==============================] - 1s 10ms/step - loss: 1.1208 - accuracy: 0.6015 - val_loss: 1.2243 - val_accuracy: 0.5659
# Epoch 21/300
# 73/79 [==========================>...] - ETA: 0s - loss: 1.1050 - accuracy: 0.6087
# Epoch 21: val_accuracy improved from 0.56650 to 0.57700, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 1.1037 - accuracy: 0.6095 - val_loss: 1.1991 - val_accuracy: 0.5770
# Epoch 22/300
# 76/79 [===========================>..] - ETA: 0s - loss: 1.0886 - accuracy: 0.6156
# Epoch 22: val_accuracy did not improve from 0.57700
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0897 - accuracy: 0.6155 - val_loss: 1.2189 - val_accuracy: 0.5727
# Epoch 23/300
# 79/79 [==============================] - ETA: 0s - loss: 1.0913 - accuracy: 0.6132
# Epoch 23: val_accuracy improved from 0.57700 to 0.58190, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 12ms/step - loss: 1.0913 - accuracy: 0.6132 - val_loss: 1.1961 - val_accuracy: 0.5819
# Epoch 24/300
# 79/79 [==============================] - ETA: 0s - loss: 1.0770 - accuracy: 0.6190
# Epoch 24: val_accuracy improved from 0.58190 to 0.58470, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 12ms/step - loss: 1.0770 - accuracy: 0.6190 - val_loss: 1.1822 - val_accuracy: 0.5847
# Epoch 25/300
# 77/79 [============================>.] - ETA: 0s - loss: 1.0654 - accuracy: 0.6233
# Epoch 25: val_accuracy did not improve from 0.58470
# 79/79 [==============================] - 1s 12ms/step - loss: 1.0649 - accuracy: 0.6234 - val_loss: 1.2069 - val_accuracy: 0.5803
# Epoch 26/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.0481 - accuracy: 0.6287
# Epoch 26: val_accuracy improved from 0.58470 to 0.59350, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 11ms/step - loss: 1.0484 - accuracy: 0.6285 - val_loss: 1.1658 - val_accuracy: 0.5935
# Epoch 27/300
# 74/79 [===========================>..] - ETA: 0s - loss: 1.0415 - accuracy: 0.6329
# Epoch 27: val_accuracy did not improve from 0.59350
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0414 - accuracy: 0.6326 - val_loss: 1.1737 - val_accuracy: 0.5927
# Epoch 28/300
# 73/79 [==========================>...] - ETA: 0s - loss: 1.0309 - accuracy: 0.6386
# Epoch 28: val_accuracy improved from 0.59350 to 0.59490, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0332 - accuracy: 0.6377 - val_loss: 1.1657 - val_accuracy: 0.5949
# Epoch 29/300
# 73/79 [==========================>...] - ETA: 0s - loss: 1.0163 - accuracy: 0.6428
# Epoch 29: val_accuracy did not improve from 0.59490
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0178 - accuracy: 0.6422 - val_loss: 1.1921 - val_accuracy: 0.5828
# Epoch 30/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.0128 - accuracy: 0.6422
# Epoch 30: val_accuracy improved from 0.59490 to 0.59830, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 11ms/step - loss: 1.0127 - accuracy: 0.6422 - val_loss: 1.1507 - val_accuracy: 0.5983
# Epoch 31/300
# 74/79 [===========================>..] - ETA: 0s - loss: 1.0024 - accuracy: 0.6464
# Epoch 31: val_accuracy improved from 0.59830 to 0.59940, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 11ms/step - loss: 1.0020 - accuracy: 0.6461 - val_loss: 1.1524 - val_accuracy: 0.5994
# Epoch 32/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9929 - accuracy: 0.6489
# Epoch 32: val_accuracy improved from 0.59940 to 0.60300, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9929 - accuracy: 0.6487 - val_loss: 1.1382 - val_accuracy: 0.6030
# Epoch 33/300
# 75/79 [===========================>..] - ETA: 0s - loss: 0.9813 - accuracy: 0.6553
# Epoch 33: val_accuracy improved from 0.60300 to 0.60690, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9816 - accuracy: 0.6554 - val_loss: 1.1257 - val_accuracy: 0.6069
# Epoch 34/300
# 76/79 [===========================>..] - ETA: 0s - loss: 0.9685 - accuracy: 0.6612
# Epoch 34: val_accuracy did not improve from 0.60690
# 79/79 [==============================] - 1s 11ms/step - loss: 0.9692 - accuracy: 0.6608 - val_loss: 1.1278 - val_accuracy: 0.6069
# Epoch 35/300
# 79/79 [==============================] - ETA: 0s - loss: 0.9647 - accuracy: 0.6614
# Epoch 35: val_accuracy improved from 0.60690 to 0.60720, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 11ms/step - loss: 0.9647 - accuracy: 0.6614 - val_loss: 1.1383 - val_accuracy: 0.6072
# Epoch 36/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9567 - accuracy: 0.6649
# Epoch 36: val_accuracy did not improve from 0.60720
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9566 - accuracy: 0.6650 - val_loss: 1.1994 - val_accuracy: 0.5867
# Epoch 37/300
# 77/79 [============================>.] - ETA: 0s - loss: 0.9558 - accuracy: 0.6641
# Epoch 37: val_accuracy did not improve from 0.60720
# 79/79 [==============================] - 1s 11ms/step - loss: 0.9558 - accuracy: 0.6641 - val_loss: 1.1489 - val_accuracy: 0.6028
# Epoch 38/300
# 74/79 [===========================>..] - ETA: 0s - loss: 0.9419 - accuracy: 0.6700
# Epoch 38: val_accuracy did not improve from 0.60720
# 79/79 [==============================] - 1s 12ms/step - loss: 0.9429 - accuracy: 0.6693 - val_loss: 1.1412 - val_accuracy: 0.6017

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:00:39.306862

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 60.260

# %%
model.load_weights('/tmp/chkpoint')

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/M7. Deep Learning/Entregable 4/" # A revisar en vuestra instancia

# model.save(ruta_googledrive+'cifar10_base_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
