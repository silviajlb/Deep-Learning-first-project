# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# # Aquí iria el codigo para conectarse a Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(256, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(256, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(256, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 128)       147584
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 256)         295168
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 256)         590080
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 256)         590080
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 1024)              4195328
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 6125578 (23.37 MB)
# Trainable params: 6125578 (23.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 5s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_acc = EarlyStopping(monitor='val_accuracy', patience=5)

modelchk = ModelCheckpoint('/tmp/chkpoint', monitor = 'val_accuracy',
                           verbose=1, save_best_only=True, save_weights_only=True)

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train,
                    callbacks=[modelchk, callback_loss, callback_acc],
                    epochs=300,
                    batch_size= 512,
                    validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - ETA: 0s - loss: 2.1558 - accuracy: 0.1903
# Epoch 1: val_accuracy improved from -inf to 0.30670, saving model to /tmp/chkpoint
# 79/79 [==============================] - 38s 234ms/step - loss: 2.1558 - accuracy: 0.1903 - val_loss: 1.8666 - val_accuracy: 0.3067
# Epoch 2/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.7420 - accuracy: 0.3474
# Epoch 2: val_accuracy improved from 0.30670 to 0.35900, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 185ms/step - loss: 1.7422 - accuracy: 0.3474 - val_loss: 1.8015 - val_accuracy: 0.3590
# Epoch 3/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.5084 - accuracy: 0.4400
# Epoch 3: val_accuracy improved from 0.35900 to 0.47670, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 190ms/step - loss: 1.5081 - accuracy: 0.4400 - val_loss: 1.4184 - val_accuracy: 0.4767
# Epoch 4/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.3188 - accuracy: 0.5164
# Epoch 4: val_accuracy improved from 0.47670 to 0.57350, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 189ms/step - loss: 1.3187 - accuracy: 0.5164 - val_loss: 1.1700 - val_accuracy: 0.5735
# Epoch 5/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.1686 - accuracy: 0.5795
# Epoch 5: val_accuracy improved from 0.57350 to 0.60460, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 191ms/step - loss: 1.1685 - accuracy: 0.5796 - val_loss: 1.0908 - val_accuracy: 0.6046
# Epoch 6/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.0542 - accuracy: 0.6220
# Epoch 6: val_accuracy improved from 0.60460 to 0.62280, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 189ms/step - loss: 1.0541 - accuracy: 0.6220 - val_loss: 1.0253 - val_accuracy: 0.6228
# Epoch 7/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9469 - accuracy: 0.6629
# Epoch 7: val_accuracy improved from 0.62280 to 0.66210, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 185ms/step - loss: 0.9467 - accuracy: 0.6630 - val_loss: 0.9728 - val_accuracy: 0.6621
# Epoch 8/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8711 - accuracy: 0.6906
# Epoch 8: val_accuracy improved from 0.66210 to 0.68460, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 184ms/step - loss: 0.8709 - accuracy: 0.6906 - val_loss: 0.8868 - val_accuracy: 0.6846
# Epoch 9/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7779 - accuracy: 0.7238
# Epoch 9: val_accuracy improved from 0.68460 to 0.73210, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 190ms/step - loss: 0.7778 - accuracy: 0.7238 - val_loss: 0.7546 - val_accuracy: 0.7321
# Epoch 10/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7168 - accuracy: 0.7478
# Epoch 10: val_accuracy improved from 0.73210 to 0.74120, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 192ms/step - loss: 0.7167 - accuracy: 0.7477 - val_loss: 0.7395 - val_accuracy: 0.7412
# Epoch 11/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6456 - accuracy: 0.7722
# Epoch 11: val_accuracy did not improve from 0.74120
# 79/79 [==============================] - 14s 180ms/step - loss: 0.6457 - accuracy: 0.7721 - val_loss: 0.7726 - val_accuracy: 0.7307
# Epoch 12/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5985 - accuracy: 0.7897
# Epoch 12: val_accuracy improved from 0.74120 to 0.76350, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 184ms/step - loss: 0.5983 - accuracy: 0.7898 - val_loss: 0.6775 - val_accuracy: 0.7635
# Epoch 13/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5540 - accuracy: 0.8055
# Epoch 13: val_accuracy improved from 0.76350 to 0.77650, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 183ms/step - loss: 0.5540 - accuracy: 0.8055 - val_loss: 0.6323 - val_accuracy: 0.7765
# Epoch 14/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5077 - accuracy: 0.8205
# Epoch 14: val_accuracy did not improve from 0.77650
# 79/79 [==============================] - 14s 180ms/step - loss: 0.5076 - accuracy: 0.8205 - val_loss: 0.6707 - val_accuracy: 0.7727
# Epoch 15/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4896 - accuracy: 0.8264
# Epoch 15: val_accuracy improved from 0.77650 to 0.78480, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 183ms/step - loss: 0.4895 - accuracy: 0.8265 - val_loss: 0.6351 - val_accuracy: 0.7848
# Epoch 16/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4532 - accuracy: 0.8394
# Epoch 16: val_accuracy did not improve from 0.78480
# 79/79 [==============================] - 15s 187ms/step - loss: 0.4532 - accuracy: 0.8394 - val_loss: 0.6604 - val_accuracy: 0.7776
# Epoch 17/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4017 - accuracy: 0.8568
# Epoch 17: val_accuracy did not improve from 0.78480
# 79/79 [==============================] - 15s 187ms/step - loss: 0.4016 - accuracy: 0.8569 - val_loss: 0.6626 - val_accuracy: 0.7822
# Epoch 18/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3680 - accuracy: 0.8688
# Epoch 18: val_accuracy improved from 0.78480 to 0.79820, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 189ms/step - loss: 0.3679 - accuracy: 0.8688 - val_loss: 0.6215 - val_accuracy: 0.7982
# Epoch 19/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3458 - accuracy: 0.8774
# Epoch 19: val_accuracy did not improve from 0.79820
# 79/79 [==============================] - 14s 181ms/step - loss: 0.3456 - accuracy: 0.8775 - val_loss: 0.6326 - val_accuracy: 0.7978
# Epoch 20/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3098 - accuracy: 0.8886
# Epoch 20: val_accuracy improved from 0.79820 to 0.80110, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 183ms/step - loss: 0.3101 - accuracy: 0.8885 - val_loss: 0.6520 - val_accuracy: 0.8011
# Epoch 21/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.2920 - accuracy: 0.8972
# Epoch 21: val_accuracy improved from 0.80110 to 0.81560, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 191ms/step - loss: 0.2919 - accuracy: 0.8972 - val_loss: 0.6114 - val_accuracy: 0.8156
# Epoch 22/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.2687 - accuracy: 0.9034
# Epoch 22: val_accuracy did not improve from 0.81560
# 79/79 [==============================] - 15s 187ms/step - loss: 0.2688 - accuracy: 0.9033 - val_loss: 0.6363 - val_accuracy: 0.8069
# Epoch 23/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.2561 - accuracy: 0.9084
# Epoch 23: val_accuracy did not improve from 0.81560
# 79/79 [==============================] - 14s 180ms/step - loss: 0.2562 - accuracy: 0.9084 - val_loss: 0.7656 - val_accuracy: 0.7802
# Epoch 24/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.2564 - accuracy: 0.9100
# Epoch 24: val_accuracy did not improve from 0.81560
# 79/79 [==============================] - 15s 187ms/step - loss: 0.2563 - accuracy: 0.9100 - val_loss: 0.6197 - val_accuracy: 0.8140
# Epoch 25/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.2103 - accuracy: 0.9263
# Epoch 25: val_accuracy improved from 0.81560 to 0.81800, saving model to /tmp/chkpoint
# 79/79 [==============================] - 15s 184ms/step - loss: 0.2106 - accuracy: 0.9262 - val_loss: 0.6584 - val_accuracy: 0.8180
# Epoch 26/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.2182 - accuracy: 0.9214
# Epoch 26: val_accuracy did not improve from 0.81800
# 79/79 [==============================] - 15s 187ms/step - loss: 0.2183 - accuracy: 0.9213 - val_loss: 0.6229 - val_accuracy: 0.8178

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:06:49.768803

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 80.760

# %%
model.load_weights('/tmp/chkpoint')

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/M7. Deep Learning/Entregable 4/" # A revisar en vuestra instancia

# model.save(ruta_googledrive+'cifar10_base_model.h5')
