# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# # Aquí iria el codigo para conectarse a Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu',
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(500, activation='relu'))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 500)               4096500
#
#  dropout (Dropout)           (None, 500)               0
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 4102406 (15.65 MB)
# Trainable params: 4102406 (15.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_acc = EarlyStopping(monitor='val_accuracy', patience=5)

modelchk = ModelCheckpoint('/tmp/chkpoint', monitor = 'val_accuracy',
                           verbose=1, save_best_only=True, save_weights_only=True)

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train,
                    callbacks=[modelchk, callback_loss, callback_acc],
                    epochs=300, batch_size= 512,
                    validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - ETA: 0s - loss: 2.0446 - accuracy: 0.2735
# Epoch 1: val_accuracy improved from -inf to 0.42830, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 31ms/step - loss: 2.0446 - accuracy: 0.2735 - val_loss: 1.6422 - val_accuracy: 0.4283
# Epoch 2/300
# 76/79 [===========================>..] - ETA: 0s - loss: 1.5901 - accuracy: 0.4301
# Epoch 2: val_accuracy improved from 0.42830 to 0.51520, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 1.5868 - accuracy: 0.4314 - val_loss: 1.4133 - val_accuracy: 0.5152
# Epoch 3/300
# 75/79 [===========================>..] - ETA: 0s - loss: 1.4252 - accuracy: 0.4899
# Epoch 3: val_accuracy improved from 0.51520 to 0.52120, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 1.4239 - accuracy: 0.4903 - val_loss: 1.3685 - val_accuracy: 0.5212
# Epoch 4/300
# 79/79 [==============================] - ETA: 0s - loss: 1.3424 - accuracy: 0.5244
# Epoch 4: val_accuracy improved from 0.52120 to 0.55040, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 1.3424 - accuracy: 0.5244 - val_loss: 1.2790 - val_accuracy: 0.5504
# Epoch 5/300
# 75/79 [===========================>..] - ETA: 0s - loss: 1.2833 - accuracy: 0.5453
# Epoch 5: val_accuracy improved from 0.55040 to 0.57230, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 16ms/step - loss: 1.2822 - accuracy: 0.5454 - val_loss: 1.2254 - val_accuracy: 0.5723
# Epoch 6/300
# 79/79 [==============================] - ETA: 0s - loss: 1.2330 - accuracy: 0.5657
# Epoch 6: val_accuracy improved from 0.57230 to 0.58480, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 1.2330 - accuracy: 0.5657 - val_loss: 1.2083 - val_accuracy: 0.5848
# Epoch 7/300
# 75/79 [===========================>..] - ETA: 0s - loss: 1.1902 - accuracy: 0.5789
# Epoch 7: val_accuracy improved from 0.58480 to 0.59690, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 1.1890 - accuracy: 0.5796 - val_loss: 1.1581 - val_accuracy: 0.5969
# Epoch 8/300
# 79/79 [==============================] - ETA: 0s - loss: 1.1472 - accuracy: 0.5959
# Epoch 8: val_accuracy improved from 0.59690 to 0.60790, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 1.1472 - accuracy: 0.5959 - val_loss: 1.1214 - val_accuracy: 0.6079
# Epoch 9/300
# 76/79 [===========================>..] - ETA: 0s - loss: 1.1107 - accuracy: 0.6067
# Epoch 9: val_accuracy improved from 0.60790 to 0.61390, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 1.1109 - accuracy: 0.6063 - val_loss: 1.1152 - val_accuracy: 0.6139
# Epoch 10/300
# 75/79 [===========================>..] - ETA: 0s - loss: 1.0871 - accuracy: 0.6184
# Epoch 10: val_accuracy improved from 0.61390 to 0.61540, saving model to /tmp/chkpoint
# 79/79 [==============================] - 2s 19ms/step - loss: 1.0872 - accuracy: 0.6184 - val_loss: 1.0974 - val_accuracy: 0.6154
# Epoch 11/300
# 79/79 [==============================] - ETA: 0s - loss: 1.0510 - accuracy: 0.6294
# Epoch 11: val_accuracy improved from 0.61540 to 0.62750, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 17ms/step - loss: 1.0510 - accuracy: 0.6294 - val_loss: 1.0580 - val_accuracy: 0.6275
# Epoch 12/300
# 75/79 [===========================>..] - ETA: 0s - loss: 1.0264 - accuracy: 0.6404
# Epoch 12: val_accuracy improved from 0.62750 to 0.63140, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 1.0255 - accuracy: 0.6401 - val_loss: 1.0634 - val_accuracy: 0.6314
# Epoch 13/300
# 75/79 [===========================>..] - ETA: 0s - loss: 0.9991 - accuracy: 0.6490
# Epoch 13: val_accuracy improved from 0.63140 to 0.63590, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 0.9995 - accuracy: 0.6484 - val_loss: 1.0458 - val_accuracy: 0.6359
# Epoch 14/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9744 - accuracy: 0.6558
# Epoch 14: val_accuracy improved from 0.63590 to 0.64720, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 16ms/step - loss: 0.9745 - accuracy: 0.6557 - val_loss: 1.0325 - val_accuracy: 0.6472
# Epoch 15/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9541 - accuracy: 0.6636
# Epoch 15: val_accuracy did not improve from 0.64720
# 79/79 [==============================] - 1s 14ms/step - loss: 0.9541 - accuracy: 0.6636 - val_loss: 1.0166 - val_accuracy: 0.6425
# Epoch 16/300
# 75/79 [===========================>..] - ETA: 0s - loss: 0.9280 - accuracy: 0.6726
# Epoch 16: val_accuracy did not improve from 0.64720
# 79/79 [==============================] - 1s 13ms/step - loss: 0.9287 - accuracy: 0.6716 - val_loss: 1.0142 - val_accuracy: 0.6465
# Epoch 17/300
# 76/79 [===========================>..] - ETA: 0s - loss: 0.9243 - accuracy: 0.6728
# Epoch 17: val_accuracy improved from 0.64720 to 0.64750, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 0.9238 - accuracy: 0.6723 - val_loss: 1.0141 - val_accuracy: 0.6475
# Epoch 18/300
# 76/79 [===========================>..] - ETA: 0s - loss: 0.8833 - accuracy: 0.6872
# Epoch 18: val_accuracy improved from 0.64750 to 0.65000, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 0.8838 - accuracy: 0.6869 - val_loss: 1.0070 - val_accuracy: 0.6500
# Epoch 19/300
# 75/79 [===========================>..] - ETA: 0s - loss: 0.8677 - accuracy: 0.6936
# Epoch 19: val_accuracy did not improve from 0.65000
# 79/79 [==============================] - 1s 13ms/step - loss: 0.8664 - accuracy: 0.6944 - val_loss: 1.0494 - val_accuracy: 0.6341
# Epoch 20/300
# 77/79 [============================>.] - ETA: 0s - loss: 0.8511 - accuracy: 0.6986
# Epoch 20: val_accuracy did not improve from 0.65000
# 79/79 [==============================] - 1s 16ms/step - loss: 0.8505 - accuracy: 0.6988 - val_loss: 1.0093 - val_accuracy: 0.6469
# Epoch 21/300
# 77/79 [============================>.] - ETA: 0s - loss: 0.8355 - accuracy: 0.7058
# Epoch 21: val_accuracy did not improve from 0.65000
# 79/79 [==============================] - 1s 18ms/step - loss: 0.8351 - accuracy: 0.7061 - val_loss: 1.0179 - val_accuracy: 0.6475
# Epoch 22/300
# 76/79 [===========================>..] - ETA: 0s - loss: 0.8177 - accuracy: 0.7130
# Epoch 22: val_accuracy improved from 0.65000 to 0.65890, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 0.8172 - accuracy: 0.7132 - val_loss: 0.9870 - val_accuracy: 0.6589
# Epoch 23/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8016 - accuracy: 0.7183
# Epoch 23: val_accuracy improved from 0.65890 to 0.66640, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 0.8013 - accuracy: 0.7184 - val_loss: 0.9659 - val_accuracy: 0.6664
# Epoch 24/300
# 75/79 [===========================>..] - ETA: 0s - loss: 0.7766 - accuracy: 0.7258
# Epoch 24: val_accuracy did not improve from 0.66640
# 79/79 [==============================] - 1s 13ms/step - loss: 0.7794 - accuracy: 0.7250 - val_loss: 0.9710 - val_accuracy: 0.6636
# Epoch 25/300
# 76/79 [===========================>..] - ETA: 0s - loss: 0.7697 - accuracy: 0.7272
# Epoch 25: val_accuracy improved from 0.66640 to 0.66850, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 16ms/step - loss: 0.7695 - accuracy: 0.7278 - val_loss: 0.9644 - val_accuracy: 0.6685
# Epoch 26/300
# 76/79 [===========================>..] - ETA: 0s - loss: 0.7520 - accuracy: 0.7349
# Epoch 26: val_accuracy did not improve from 0.66850
# 79/79 [==============================] - 1s 14ms/step - loss: 0.7502 - accuracy: 0.7355 - val_loss: 0.9783 - val_accuracy: 0.6660
# Epoch 27/300
# 75/79 [===========================>..] - ETA: 0s - loss: 0.7325 - accuracy: 0.7399
# Epoch 27: val_accuracy improved from 0.66850 to 0.67100, saving model to /tmp/chkpoint
# 79/79 [==============================] - 1s 15ms/step - loss: 0.7332 - accuracy: 0.7394 - val_loss: 0.9676 - val_accuracy: 0.6710
# Epoch 28/300
# 75/79 [===========================>..] - ETA: 0s - loss: 0.7198 - accuracy: 0.7454
# Epoch 28: val_accuracy did not improve from 0.67100
# 79/79 [==============================] - 1s 13ms/step - loss: 0.7195 - accuracy: 0.7450 - val_loss: 0.9936 - val_accuracy: 0.6616
# Epoch 29/300
# 75/79 [===========================>..] - ETA: 0s - loss: 0.7047 - accuracy: 0.7509
# Epoch 29: val_accuracy did not improve from 0.67100
# 79/79 [==============================] - 1s 14ms/step - loss: 0.7034 - accuracy: 0.7512 - val_loss: 0.9981 - val_accuracy: 0.6627
# Epoch 30/300
# 75/79 [===========================>..] - ETA: 0s - loss: 0.6841 - accuracy: 0.7583
# Epoch 30: val_accuracy did not improve from 0.67100
# 79/79 [==============================] - 1s 14ms/step - loss: 0.6838 - accuracy: 0.7580 - val_loss: 1.0098 - val_accuracy: 0.6643

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:00:43.293878

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 65.360

# %%
model.load_weights('/tmp/chkpoint')

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-20ddcb7bf610> in <cell line: 11>()
#      13   plot_image(i+start, predictions[i+start], y_test, x_test)
#      14   plt.subplot(num_rows, 2*num_cols, 2*i+2)
# ---> 15   plot_value_array(i+start, predictions[i+start], y_test)
#      16 plt.tight_layout()
#      17 plt.show()
#
# <ipython-input-20-7193df0c36f8> in plot_value_array(i, predictions_array, true_label)
#      21   predictions_array, true_label = predictions_array, true_label[i]
#      22   plt.grid(False)
# ---> 23   plt.xticks(range(10))
#      24   plt.yticks([])
#      25   thisplot = plt.bar(range(10), predictions_array, color="#777777")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in xticks(ticks, labels, minor, **kwargs)
#    1884                             "without setting 'ticks'")
#    1885     else:
# -> 1886         locs = ax.set_xticks(ticks, minor=minor)
#    1887
#    1888     if labels is None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      72
#      73         def wrapper(self, *args, **kwargs):
# ---> 74             return get_method(self)(*args, **kwargs)
#      75
#      76         wrapper.__module__ = owner.__module__
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in set_ticks(self, ticks, labels, minor, **kwargs)
#    2072             raise ValueError('labels argument cannot be None when '
#    2073                              'kwargs are passed')
# -> 2074         result = self._set_tick_locations(ticks, minor=minor)
#    2075         if labels is not None:
#    2076             self.set_ticklabels(labels, minor=minor, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _set_tick_locations(self, ticks, minor)
#    2033         else:
#    2034             self.set_major_locator(locator)
# -> 2035             return self.get_major_ticks(len(ticks))
#    2036
#    2037     def set_ticks(self, ticks, labels=None, *, minor=False, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1600         while len(self.majorTicks) < numticks:
#    1601             # Update the new tick label properties from the old.
# -> 1602             tick = self._get_tick(major=True)
#    1603             self.majorTicks.append(tick)
#    1604             self._copy_tick_props(self.majorTicks[0], tick)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _get_tick(self, major)
#    1549                 "_tick_class or reimplement _get_tick()")
#    1550         tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1551         return self._tick_class(self.axes, 0, major=major, **tick_kw)
#    1552
#    1553     def _get_tick_label_size(self, axis_name):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     415
#     416     def __init__(self, *args, **kwargs):
# --> 417         super().__init__(*args, **kwargs)
#     418         # x in data coords, y in axes coords
#     419         ax = self.axes
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in __init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     181             rotation=self._labelrotation[1])
#     182
# --> 183         self._apply_tickdir(tickdir)
#     184
#     185         for artist in [self.tick1line, self.tick2line, self.gridline,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _apply_tickdir(self, tickdir)
#     450             'inout': ('|', '|'),
#     451         }[self._tickdir]
# --> 452         self.tick1line.set_marker(mark1)
#     453         self.tick2line.set_marker(mark2)
#     454
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/lines.py in set_marker(self, marker)
#    1191             arguments.
#    1192         """
# -> 1193         self._marker = MarkerStyle(marker, self._marker.get_fillstyle())
#    1194         self.stale = True
#    1195
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/markers.py in __init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     270                 "%(since)s; support will be removed %(removal)s.  Use "
#     271                 "MarkerStyle('') to construct an empty MarkerStyle.")
# --> 272         self._set_marker(marker)
#     273
#     274     __init__.__signature__ = inspect.signature(  # Only for deprecation period.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/markers.py in _set_marker(self, marker)
#     365         if not isinstance(marker, MarkerStyle):
#     366             self._marker = marker
# --> 367             self._recache()
#     368
#     369     def get_path(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/markers.py in _recache(self)
#     289         # markers.
#     290         self._filled = self._fillstyle != 'none'
# --> 291         self._marker_function()
#     292
#     293     def __bool__(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/markers.py in _set_tickdown(self)
#     810
#     811     def _set_tickdown(self):
# --> 812         self._transform = Affine2D().scale(1.0, -1.0)
#     813         self._snap_threshold = 1.0
#     814         self._filled = False
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/transforms.py in __init__(self, matrix, **kwargs)
#    1893             # A bit faster than np.identity(3).
#    1894             matrix = IdentityTransform._mtx
# -> 1895         self._mtx = matrix.copy()
#    1896         self._invalid = 0
#    1897
#
# KeyboardInterrupt:

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/M7. Deep Learning/Entregable 4/" # A revisar en vuestra instancia

# model.save(ruta_googledrive+'cifar10_base_model.h5')
