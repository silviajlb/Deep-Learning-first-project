# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# # Aquí iria el codigo para conectarse a Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

# Primera capa de convolución
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(Dropout(0.4))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Dropout(0.4))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))


# Segunda capa de convolución
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Dropout(0.4))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Dropout(0.4))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))


# Tercera capa de convolución
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Dropout(0.4))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Dropout(0.4))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))


model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        896
#
#  dropout_10 (Dropout)        (None, 32, 32, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 32)        9248
#
#  dropout_11 (Dropout)        (None, 32, 32, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 64)        18496
#
#  dropout_12 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 64)        36928
#
#  dropout_13 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_4 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 128)         73856
#
#  dropout_14 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 128)         147584
#
#  dropout_15 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_5 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 500)               1024500
#
#  dropout_16 (Dropout)        (None, 500)               0
#
#  dense_3 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 1510278 (5.76 MB)
# Trainable params: 1510278 (5.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_acc = EarlyStopping(monitor='val_accuracy', patience=5)

modelchk = ModelCheckpoint('/tmp/chkpoint', monitor = 'val_accuracy',
                           verbose=1, save_best_only=True, save_weights_only=True)

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train,
                    callbacks=[modelchk, callback_loss, callback_acc],
                    epochs=300,
                    batch_size= 512,
                    validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/300
# 78/79 [============================>.] - ETA: 0s - loss: 2.1154 - accuracy: 0.2154
# Epoch 1: val_accuracy improved from -inf to 0.17320, saving model to /tmp/chkpoint
# 79/79 [==============================] - 12s 101ms/step - loss: 2.1151 - accuracy: 0.2157 - val_loss: 2.2613 - val_accuracy: 0.1732
# Epoch 2/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.8301 - accuracy: 0.3174
# Epoch 2: val_accuracy improved from 0.17320 to 0.28040, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 94ms/step - loss: 1.8295 - accuracy: 0.3177 - val_loss: 2.0242 - val_accuracy: 0.2804
# Epoch 3/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.6298 - accuracy: 0.3992
# Epoch 3: val_accuracy improved from 0.28040 to 0.33990, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 96ms/step - loss: 1.6302 - accuracy: 0.3991 - val_loss: 1.9002 - val_accuracy: 0.3399
# Epoch 4/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.5041 - accuracy: 0.4501
# Epoch 4: val_accuracy improved from 0.33990 to 0.44470, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 95ms/step - loss: 1.5040 - accuracy: 0.4502 - val_loss: 1.5422 - val_accuracy: 0.4447
# Epoch 5/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.4008 - accuracy: 0.4882
# Epoch 5: val_accuracy improved from 0.44470 to 0.49510, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 100ms/step - loss: 1.4006 - accuracy: 0.4884 - val_loss: 1.3744 - val_accuracy: 0.4951
# Epoch 6/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.3311 - accuracy: 0.5162
# Epoch 6: val_accuracy improved from 0.49510 to 0.53680, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 99ms/step - loss: 1.3308 - accuracy: 0.5162 - val_loss: 1.2973 - val_accuracy: 0.5368
# Epoch 7/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.2560 - accuracy: 0.5444
# Epoch 7: val_accuracy did not improve from 0.53680
# 79/79 [==============================] - 8s 98ms/step - loss: 1.2558 - accuracy: 0.5445 - val_loss: 1.3343 - val_accuracy: 0.5306
# Epoch 8/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.1841 - accuracy: 0.5757
# Epoch 8: val_accuracy improved from 0.53680 to 0.57890, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 95ms/step - loss: 1.1838 - accuracy: 0.5757 - val_loss: 1.1901 - val_accuracy: 0.5789
# Epoch 9/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.1283 - accuracy: 0.5937
# Epoch 9: val_accuracy improved from 0.57890 to 0.60770, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 98ms/step - loss: 1.1281 - accuracy: 0.5938 - val_loss: 1.0903 - val_accuracy: 0.6077
# Epoch 10/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.0722 - accuracy: 0.6168
# Epoch 10: val_accuracy improved from 0.60770 to 0.63140, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 99ms/step - loss: 1.0724 - accuracy: 0.6166 - val_loss: 1.0433 - val_accuracy: 0.6314
# Epoch 11/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.0235 - accuracy: 0.6366
# Epoch 11: val_accuracy improved from 0.63140 to 0.66230, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 98ms/step - loss: 1.0235 - accuracy: 0.6367 - val_loss: 0.9709 - val_accuracy: 0.6623
# Epoch 12/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9885 - accuracy: 0.6469
# Epoch 12: val_accuracy did not improve from 0.66230
# 79/79 [==============================] - 8s 103ms/step - loss: 0.9884 - accuracy: 0.6470 - val_loss: 0.9889 - val_accuracy: 0.6604
# Epoch 13/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9427 - accuracy: 0.6672
# Epoch 13: val_accuracy improved from 0.66230 to 0.67170, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 97ms/step - loss: 0.9429 - accuracy: 0.6671 - val_loss: 0.9549 - val_accuracy: 0.6717
# Epoch 14/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9107 - accuracy: 0.6771
# Epoch 14: val_accuracy improved from 0.67170 to 0.67880, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 99ms/step - loss: 0.9108 - accuracy: 0.6771 - val_loss: 0.9199 - val_accuracy: 0.6788
# Epoch 15/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8763 - accuracy: 0.6899
# Epoch 15: val_accuracy improved from 0.67880 to 0.69070, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 94ms/step - loss: 0.8766 - accuracy: 0.6898 - val_loss: 0.8906 - val_accuracy: 0.6907
# Epoch 16/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8497 - accuracy: 0.6969
# Epoch 16: val_accuracy did not improve from 0.69070
# 79/79 [==============================] - 7s 94ms/step - loss: 0.8497 - accuracy: 0.6969 - val_loss: 0.9606 - val_accuracy: 0.6717
# Epoch 17/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8248 - accuracy: 0.7096
# Epoch 17: val_accuracy did not improve from 0.69070
# 79/79 [==============================] - 7s 93ms/step - loss: 0.8245 - accuracy: 0.7096 - val_loss: 1.0170 - val_accuracy: 0.6644
# Epoch 18/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7988 - accuracy: 0.7173
# Epoch 18: val_accuracy improved from 0.69070 to 0.71640, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 99ms/step - loss: 0.7988 - accuracy: 0.7173 - val_loss: 0.8342 - val_accuracy: 0.7164
# Epoch 19/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7754 - accuracy: 0.7206
# Epoch 19: val_accuracy improved from 0.71640 to 0.72210, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 99ms/step - loss: 0.7756 - accuracy: 0.7206 - val_loss: 0.8067 - val_accuracy: 0.7221
# Epoch 20/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7536 - accuracy: 0.7330
# Epoch 20: val_accuracy did not improve from 0.72210
# 79/79 [==============================] - 7s 92ms/step - loss: 0.7537 - accuracy: 0.7329 - val_loss: 0.8333 - val_accuracy: 0.7155
# Epoch 21/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7400 - accuracy: 0.7381
# Epoch 21: val_accuracy improved from 0.72210 to 0.72270, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 95ms/step - loss: 0.7396 - accuracy: 0.7382 - val_loss: 0.8035 - val_accuracy: 0.7227
# Epoch 22/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7236 - accuracy: 0.7436
# Epoch 22: val_accuracy improved from 0.72270 to 0.73660, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 95ms/step - loss: 0.7234 - accuracy: 0.7437 - val_loss: 0.7628 - val_accuracy: 0.7366
# Epoch 23/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6948 - accuracy: 0.7546
# Epoch 23: val_accuracy improved from 0.73660 to 0.73690, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 95ms/step - loss: 0.6948 - accuracy: 0.7546 - val_loss: 0.7568 - val_accuracy: 0.7369
# Epoch 24/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6881 - accuracy: 0.7568
# Epoch 24: val_accuracy did not improve from 0.73690
# 79/79 [==============================] - 8s 96ms/step - loss: 0.6881 - accuracy: 0.7568 - val_loss: 0.7798 - val_accuracy: 0.7324
# Epoch 25/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6693 - accuracy: 0.7629
# Epoch 25: val_accuracy improved from 0.73690 to 0.74130, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 98ms/step - loss: 0.6693 - accuracy: 0.7628 - val_loss: 0.7626 - val_accuracy: 0.7413
# Epoch 26/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6558 - accuracy: 0.7671
# Epoch 26: val_accuracy improved from 0.74130 to 0.76440, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 99ms/step - loss: 0.6558 - accuracy: 0.7671 - val_loss: 0.6962 - val_accuracy: 0.7644
# Epoch 27/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6470 - accuracy: 0.7706
# Epoch 27: val_accuracy did not improve from 0.76440
# 79/79 [==============================] - 7s 93ms/step - loss: 0.6474 - accuracy: 0.7705 - val_loss: 0.7567 - val_accuracy: 0.7427
# Epoch 28/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6318 - accuracy: 0.7772
# Epoch 28: val_accuracy did not improve from 0.76440
# 79/79 [==============================] - 7s 93ms/step - loss: 0.6319 - accuracy: 0.7771 - val_loss: 0.7235 - val_accuracy: 0.7587
# Epoch 29/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6082 - accuracy: 0.7821
# Epoch 29: val_accuracy did not improve from 0.76440
# 79/79 [==============================] - 7s 93ms/step - loss: 0.6083 - accuracy: 0.7821 - val_loss: 0.8018 - val_accuracy: 0.7353
# Epoch 30/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6077 - accuracy: 0.7849
# Epoch 30: val_accuracy did not improve from 0.76440
# 79/79 [==============================] - 8s 97ms/step - loss: 0.6078 - accuracy: 0.7849 - val_loss: 0.7682 - val_accuracy: 0.7407
# Epoch 31/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5960 - accuracy: 0.7882
# Epoch 31: val_accuracy did not improve from 0.76440
# 79/79 [==============================] - 8s 97ms/step - loss: 0.5959 - accuracy: 0.7883 - val_loss: 0.7784 - val_accuracy: 0.7380

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:04:03.381738

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 73.480

# %%
model.load_weights('/tmp/chkpoint')

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/M7. Deep Learning/Entregable 4/" # A revisar en vuestra instancia

# model.save(ruta_googledrive+'cifar10_base_model.h5')
