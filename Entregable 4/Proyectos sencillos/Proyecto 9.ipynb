# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# # Aquí iria el codigo para conectarse a Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 128)       147584
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 256)         295168
#
#  batch_normalization (Batch  (None, 8, 8, 256)         1024
#  Normalization)
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 256)         590080
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 256)         590080
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 500)               2048500
#
#  dropout_3 (Dropout)         (None, 500)               0
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 3974534 (15.16 MB)
# Trainable params: 3974022 (15.16 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_acc = EarlyStopping(monitor='val_accuracy', patience=5)

modelchk = ModelCheckpoint('/tmp/chkpoint', monitor = 'val_accuracy',
                           verbose=1, save_best_only=True, save_weights_only=True)

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train,
                    callbacks=[modelchk, callback_loss, callback_acc],
                    epochs=300,
                    batch_size= 512,
                    validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - ETA: 0s - loss: 1.9574 - accuracy: 0.2604
# Epoch 1: val_accuracy improved from -inf to 0.27540, saving model to /tmp/chkpoint
# 79/79 [==============================] - 30s 211ms/step - loss: 1.9574 - accuracy: 0.2604 - val_loss: 2.2106 - val_accuracy: 0.2754
# Epoch 2/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.5066 - accuracy: 0.4425
# Epoch 2: val_accuracy improved from 0.27540 to 0.38920, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 180ms/step - loss: 1.5061 - accuracy: 0.4428 - val_loss: 2.1230 - val_accuracy: 0.3892
# Epoch 3/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.2496 - accuracy: 0.5475
# Epoch 3: val_accuracy improved from 0.38920 to 0.45540, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 181ms/step - loss: 1.2497 - accuracy: 0.5475 - val_loss: 1.9791 - val_accuracy: 0.4554
# Epoch 4/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.0883 - accuracy: 0.6106
# Epoch 4: val_accuracy improved from 0.45540 to 0.62950, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 175ms/step - loss: 1.0880 - accuracy: 0.6107 - val_loss: 1.8378 - val_accuracy: 0.6295
# Epoch 5/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9559 - accuracy: 0.6621
# Epoch 5: val_accuracy did not improve from 0.62950
# 79/79 [==============================] - 14s 174ms/step - loss: 0.9558 - accuracy: 0.6622 - val_loss: 1.5288 - val_accuracy: 0.6277
# Epoch 6/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8569 - accuracy: 0.6995
# Epoch 6: val_accuracy improved from 0.62950 to 0.66520, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 179ms/step - loss: 0.8570 - accuracy: 0.6995 - val_loss: 1.3033 - val_accuracy: 0.6652
# Epoch 7/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7857 - accuracy: 0.7232
# Epoch 7: val_accuracy improved from 0.66520 to 0.67040, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 177ms/step - loss: 0.7856 - accuracy: 0.7233 - val_loss: 0.9846 - val_accuracy: 0.6704
# Epoch 8/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7119 - accuracy: 0.7499
# Epoch 8: val_accuracy improved from 0.67040 to 0.69640, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 182ms/step - loss: 0.7116 - accuracy: 0.7499 - val_loss: 0.8819 - val_accuracy: 0.6964
# Epoch 9/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6527 - accuracy: 0.7705
# Epoch 9: val_accuracy improved from 0.69640 to 0.73010, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 176ms/step - loss: 0.6523 - accuracy: 0.7706 - val_loss: 0.7614 - val_accuracy: 0.7301
# Epoch 10/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6218 - accuracy: 0.7824
# Epoch 10: val_accuracy improved from 0.73010 to 0.74090, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 176ms/step - loss: 0.6220 - accuracy: 0.7824 - val_loss: 0.7491 - val_accuracy: 0.7409
# Epoch 11/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5685 - accuracy: 0.7982
# Epoch 11: val_accuracy improved from 0.74090 to 0.76060, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 177ms/step - loss: 0.5691 - accuracy: 0.7980 - val_loss: 0.6964 - val_accuracy: 0.7606
# Epoch 12/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5349 - accuracy: 0.8125
# Epoch 12: val_accuracy improved from 0.76060 to 0.76840, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 176ms/step - loss: 0.5350 - accuracy: 0.8124 - val_loss: 0.6829 - val_accuracy: 0.7684
# Epoch 13/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5073 - accuracy: 0.8194
# Epoch 13: val_accuracy did not improve from 0.76840
# 79/79 [==============================] - 14s 181ms/step - loss: 0.5074 - accuracy: 0.8194 - val_loss: 0.7575 - val_accuracy: 0.7600
# Epoch 14/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4752 - accuracy: 0.8326
# Epoch 14: val_accuracy improved from 0.76840 to 0.80610, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 176ms/step - loss: 0.4753 - accuracy: 0.8325 - val_loss: 0.5713 - val_accuracy: 0.8061
# Epoch 15/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4527 - accuracy: 0.8385
# Epoch 15: val_accuracy did not improve from 0.80610
# 79/79 [==============================] - 14s 174ms/step - loss: 0.4525 - accuracy: 0.8385 - val_loss: 0.5954 - val_accuracy: 0.8052
# Epoch 16/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4275 - accuracy: 0.8491
# Epoch 16: val_accuracy did not improve from 0.80610
# 79/79 [==============================] - 14s 174ms/step - loss: 0.4276 - accuracy: 0.8490 - val_loss: 0.5843 - val_accuracy: 0.8061
# Epoch 17/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4001 - accuracy: 0.8587
# Epoch 17: val_accuracy did not improve from 0.80610
# 79/79 [==============================] - 14s 174ms/step - loss: 0.4001 - accuracy: 0.8587 - val_loss: 0.5990 - val_accuracy: 0.8026
# Epoch 18/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3770 - accuracy: 0.8663
# Epoch 18: val_accuracy improved from 0.80610 to 0.82190, saving model to /tmp/chkpoint
# 79/79 [==============================] - 14s 183ms/step - loss: 0.3768 - accuracy: 0.8663 - val_loss: 0.5597 - val_accuracy: 0.8219
# Epoch 19/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3620 - accuracy: 0.8722
# Epoch 19: val_accuracy did not improve from 0.82190
# 79/79 [==============================] - 14s 174ms/step - loss: 0.3624 - accuracy: 0.8721 - val_loss: 0.6244 - val_accuracy: 0.8069
# Epoch 20/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3457 - accuracy: 0.8769
# Epoch 20: val_accuracy did not improve from 0.82190
# 79/79 [==============================] - 14s 180ms/step - loss: 0.3456 - accuracy: 0.8770 - val_loss: 0.6604 - val_accuracy: 0.8020
# Epoch 21/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3264 - accuracy: 0.8840
# Epoch 21: val_accuracy did not improve from 0.82190
# 79/79 [==============================] - 14s 174ms/step - loss: 0.3264 - accuracy: 0.8839 - val_loss: 1.0477 - val_accuracy: 0.7409
# Epoch 22/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3116 - accuracy: 0.8891
# Epoch 22: val_accuracy did not improve from 0.82190
# 79/79 [==============================] - 14s 180ms/step - loss: 0.3118 - accuracy: 0.8890 - val_loss: 0.6054 - val_accuracy: 0.8144
# Epoch 23/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.2970 - accuracy: 0.8948
# Epoch 23: val_accuracy did not improve from 0.82190
# 79/79 [==============================] - 14s 174ms/step - loss: 0.2972 - accuracy: 0.8946 - val_loss: 0.6456 - val_accuracy: 0.8089

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:05:42.147241

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 80.790

# %%
model.load_weights('/tmp/chkpoint')

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/M7. Deep Learning/Entregable 4/" # A revisar en vuestra instancia

# model.save(ruta_googledrive+'cifar10_base_model.h5')
