# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# # Aquí iria el codigo para conectarse a Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  dropout_1 (Dropout)         (None, 32, 32, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        18496
#
#  dropout_2 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        36928
#
#  dropout_3 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         73856
#
#  dropout_4 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 128)         147584
#
#  dropout_5 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 500)               1024500
#
#  dropout_6 (Dropout)         (None, 500)               0
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 1510278 (5.76 MB)
# Trainable params: 1510278 (5.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_acc = EarlyStopping(monitor='val_accuracy', patience=5)

modelchk = ModelCheckpoint('/tmp/chkpoint', monitor = 'val_accuracy',
                           verbose=1, save_best_only=True, save_weights_only=True)

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train,
                    callbacks=[modelchk, callback_loss, callback_acc],
                    epochs=300,
                    batch_size= 512,
                    validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/300
# 79/79 [==============================] - ETA: 0s - loss: 2.0596 - accuracy: 0.2313
# Epoch 1: val_accuracy improved from -inf to 0.23440, saving model to /tmp/chkpoint
# 79/79 [==============================] - 21s 119ms/step - loss: 2.0596 - accuracy: 0.2313 - val_loss: 2.0884 - val_accuracy: 0.2344
# Epoch 2/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.7417 - accuracy: 0.3601
# Epoch 2: val_accuracy improved from 0.23440 to 0.42590, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 97ms/step - loss: 1.7414 - accuracy: 0.3602 - val_loss: 1.5913 - val_accuracy: 0.4259
# Epoch 3/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.5243 - accuracy: 0.4439
# Epoch 3: val_accuracy improved from 0.42590 to 0.48750, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 105ms/step - loss: 1.5243 - accuracy: 0.4439 - val_loss: 1.3970 - val_accuracy: 0.4875
# Epoch 4/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.3861 - accuracy: 0.4947
# Epoch 4: val_accuracy improved from 0.48750 to 0.52880, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 93ms/step - loss: 1.3855 - accuracy: 0.4949 - val_loss: 1.2920 - val_accuracy: 0.5288
# Epoch 5/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.2697 - accuracy: 0.5403
# Epoch 5: val_accuracy improved from 0.52880 to 0.56190, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 93ms/step - loss: 1.2692 - accuracy: 0.5405 - val_loss: 1.2139 - val_accuracy: 0.5619
# Epoch 6/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.1879 - accuracy: 0.5707
# Epoch 6: val_accuracy improved from 0.56190 to 0.58660, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 93ms/step - loss: 1.1875 - accuracy: 0.5708 - val_loss: 1.1523 - val_accuracy: 0.5866
# Epoch 7/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.1010 - accuracy: 0.6080
# Epoch 7: val_accuracy improved from 0.58660 to 0.60770, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 94ms/step - loss: 1.1009 - accuracy: 0.6080 - val_loss: 1.1022 - val_accuracy: 0.6077
# Epoch 8/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.0308 - accuracy: 0.6322
# Epoch 8: val_accuracy did not improve from 0.60770
# 79/79 [==============================] - 8s 98ms/step - loss: 1.0305 - accuracy: 0.6324 - val_loss: 1.0968 - val_accuracy: 0.6068
# Epoch 9/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9584 - accuracy: 0.6603
# Epoch 9: val_accuracy improved from 0.60770 to 0.68030, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 100ms/step - loss: 0.9582 - accuracy: 0.6603 - val_loss: 0.9098 - val_accuracy: 0.6803
# Epoch 10/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8896 - accuracy: 0.6854
# Epoch 10: val_accuracy did not improve from 0.68030
# 79/79 [==============================] - 8s 95ms/step - loss: 0.8898 - accuracy: 0.6853 - val_loss: 0.9724 - val_accuracy: 0.6600
# Epoch 11/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8410 - accuracy: 0.7037
# Epoch 11: val_accuracy did not improve from 0.68030
# 79/79 [==============================] - 8s 98ms/step - loss: 0.8415 - accuracy: 0.7035 - val_loss: 0.9524 - val_accuracy: 0.6662
# Epoch 12/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7924 - accuracy: 0.7213
# Epoch 12: val_accuracy improved from 0.68030 to 0.70530, saving model to /tmp/chkpoint
# 79/79 [==============================] - 8s 97ms/step - loss: 0.7924 - accuracy: 0.7211 - val_loss: 0.8619 - val_accuracy: 0.7053
# Epoch 13/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7392 - accuracy: 0.7367
# Epoch 13: val_accuracy did not improve from 0.70530
# 79/79 [==============================] - 7s 95ms/step - loss: 0.7399 - accuracy: 0.7365 - val_loss: 0.8679 - val_accuracy: 0.6954
# Epoch 14/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7047 - accuracy: 0.7519
# Epoch 14: val_accuracy improved from 0.70530 to 0.72880, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 93ms/step - loss: 0.7049 - accuracy: 0.7519 - val_loss: 0.7879 - val_accuracy: 0.7288
# Epoch 15/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6597 - accuracy: 0.7659
# Epoch 15: val_accuracy improved from 0.72880 to 0.73500, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 94ms/step - loss: 0.6597 - accuracy: 0.7659 - val_loss: 0.7967 - val_accuracy: 0.7350
# Epoch 16/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6201 - accuracy: 0.7807
# Epoch 16: val_accuracy did not improve from 0.73500
# 79/79 [==============================] - 7s 93ms/step - loss: 0.6205 - accuracy: 0.7805 - val_loss: 0.7718 - val_accuracy: 0.7336
# Epoch 17/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5994 - accuracy: 0.7870
# Epoch 17: val_accuracy improved from 0.73500 to 0.75530, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 93ms/step - loss: 0.5994 - accuracy: 0.7870 - val_loss: 0.7247 - val_accuracy: 0.7553
# Epoch 18/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5594 - accuracy: 0.8014
# Epoch 18: val_accuracy did not improve from 0.75530
# 79/79 [==============================] - 7s 93ms/step - loss: 0.5599 - accuracy: 0.8013 - val_loss: 0.7541 - val_accuracy: 0.7487
# Epoch 19/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5353 - accuracy: 0.8096
# Epoch 19: val_accuracy improved from 0.75530 to 0.75680, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 94ms/step - loss: 0.5352 - accuracy: 0.8097 - val_loss: 0.7313 - val_accuracy: 0.7568
# Epoch 20/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4954 - accuracy: 0.8241
# Epoch 20: val_accuracy improved from 0.75680 to 0.76330, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 94ms/step - loss: 0.4951 - accuracy: 0.8242 - val_loss: 0.7301 - val_accuracy: 0.7633
# Epoch 21/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4803 - accuracy: 0.8305
# Epoch 21: val_accuracy did not improve from 0.76330
# 79/79 [==============================] - 7s 93ms/step - loss: 0.4806 - accuracy: 0.8304 - val_loss: 0.7349 - val_accuracy: 0.7593
# Epoch 22/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4695 - accuracy: 0.8316
# Epoch 22: val_accuracy did not improve from 0.76330
# 79/79 [==============================] - 7s 93ms/step - loss: 0.4694 - accuracy: 0.8317 - val_loss: 0.7201 - val_accuracy: 0.7597
# Epoch 23/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4398 - accuracy: 0.8441
# Epoch 23: val_accuracy did not improve from 0.76330
# 79/79 [==============================] - 7s 93ms/step - loss: 0.4399 - accuracy: 0.8441 - val_loss: 0.7452 - val_accuracy: 0.7586
# Epoch 24/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4184 - accuracy: 0.8511
# Epoch 24: val_accuracy improved from 0.76330 to 0.77840, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 94ms/step - loss: 0.4183 - accuracy: 0.8511 - val_loss: 0.7002 - val_accuracy: 0.7784
# Epoch 25/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3923 - accuracy: 0.8592
# Epoch 25: val_accuracy did not improve from 0.77840
# 79/79 [==============================] - 7s 92ms/step - loss: 0.3922 - accuracy: 0.8592 - val_loss: 0.7331 - val_accuracy: 0.7754
# Epoch 26/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3723 - accuracy: 0.8674
# Epoch 26: val_accuracy did not improve from 0.77840
# 79/79 [==============================] - 7s 93ms/step - loss: 0.3722 - accuracy: 0.8674 - val_loss: 0.7903 - val_accuracy: 0.7705
# Epoch 27/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3593 - accuracy: 0.8706
# Epoch 27: val_accuracy did not improve from 0.77840
# 79/79 [==============================] - 8s 97ms/step - loss: 0.3594 - accuracy: 0.8705 - val_loss: 0.7639 - val_accuracy: 0.7664
# Epoch 28/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3584 - accuracy: 0.8720
# Epoch 28: val_accuracy did not improve from 0.77840
# 79/79 [==============================] - 7s 93ms/step - loss: 0.3587 - accuracy: 0.8719 - val_loss: 0.7460 - val_accuracy: 0.7757
# Epoch 29/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3508 - accuracy: 0.8757
# Epoch 29: val_accuracy did not improve from 0.77840
# 79/79 [==============================] - 7s 93ms/step - loss: 0.3508 - accuracy: 0.8756 - val_loss: 0.7507 - val_accuracy: 0.7775

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:03:54.632532

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 77.510

# %%
model.load_weights('/tmp/chkpoint')

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/M7. Deep Learning/Entregable 4/" # A revisar en vuestra instancia

# model.save(ruta_googledrive+'cifar10_base_model.h5')
