# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# # Aquí iria el codigo para conectarse a Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization

# %%
# prueba 1
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.regularizers import l2


model = Sequential()

# Primera capa de convolución
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3),
                           kernel_regularizer=L2(0.001), kernel_initializer='he_uniform'))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same',
                           kernel_regularizer=L2(0.001), kernel_initializer='he_uniform'))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same',
                           kernel_regularizer=L2(0.001), kernel_initializer='he_uniform'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))


# Segunda capa de convolución
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same',
                           kernel_regularizer=L2(0.001), kernel_initializer='he_uniform'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same',
                           kernel_regularizer=L2(0.001), kernel_initializer='he_uniform'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same',
                           kernel_regularizer=L2(0.001), kernel_initializer='he_uniform'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))


# Tercera capa de convolución
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same',
                           kernel_regularizer=L2(0.001), kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same',
                           kernel_regularizer=L2(0.001), kernel_initializer='he_uniform'))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same',
                           kernel_regularizer=L2(0.001), kernel_initializer='he_uniform'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(500, activation='relu',
                           kernel_regularizer=L2(0.001), kernel_initializer='he_uniform'))
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 32)        9248
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_6 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_21 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_22 (Conv2D)          (None, 16, 16, 64)        36928
#
#  conv2d_23 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_24 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_3 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  conv2d_25 (Conv2D)          (None, 8, 8, 128)         147584
#
#  conv2d_26 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_8 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 4, 4, 128)         0
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 500)               1024500
#
#  dropout_11 (Dropout)        (None, 500)               0
#
#  dense_5 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 1510790 (5.76 MB)
# Trainable params: 1510534 (5.76 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
# model.compile(optimizer='Adam',
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])

# %%
from tensorflow.keras.optimizers import SGD


new_sgd = SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss='sparse_categorical_crossentropy', optimizer=new_sgd, metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_acc = EarlyStopping(monitor='val_accuracy', patience=5)

modelchk = ModelCheckpoint('/tmp/chkpoint', monitor = 'val_accuracy',
                           verbose=1, save_best_only=True, save_weights_only=True)

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train,
                    callbacks=[modelchk, callback_loss, callback_acc],
                    epochs=300,
                    batch_size= 512,
                    validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.9670 - accuracy: 0.2599
# Epoch 1: val_accuracy improved from -inf to 0.20310, saving model to /tmp/chkpoint
# 79/79 [==============================] - 11s 94ms/step - loss: 1.9665 - accuracy: 0.2600 - val_loss: 2.2113 - val_accuracy: 0.2031
# Epoch 2/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.5207 - accuracy: 0.4427
# Epoch 2: val_accuracy improved from 0.20310 to 0.33150, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 90ms/step - loss: 1.5205 - accuracy: 0.4428 - val_loss: 2.1834 - val_accuracy: 0.3315
# Epoch 3/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.3194 - accuracy: 0.5225
# Epoch 3: val_accuracy improved from 0.33150 to 0.43290, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 94ms/step - loss: 1.3193 - accuracy: 0.5224 - val_loss: 2.0984 - val_accuracy: 0.4329
# Epoch 4/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.1825 - accuracy: 0.5735
# Epoch 4: val_accuracy improved from 0.43290 to 0.54320, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 1.1822 - accuracy: 0.5737 - val_loss: 1.8780 - val_accuracy: 0.5432
# Epoch 5/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.0827 - accuracy: 0.6119
# Epoch 5: val_accuracy improved from 0.54320 to 0.63170, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 87ms/step - loss: 1.0830 - accuracy: 0.6118 - val_loss: 1.5830 - val_accuracy: 0.6317
# Epoch 6/300
# 78/79 [============================>.] - ETA: 0s - loss: 1.0061 - accuracy: 0.6425
# Epoch 6: val_accuracy improved from 0.63170 to 0.65320, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 88ms/step - loss: 1.0062 - accuracy: 0.6424 - val_loss: 1.3655 - val_accuracy: 0.6532
# Epoch 7/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.9288 - accuracy: 0.6688
# Epoch 7: val_accuracy did not improve from 0.65320
# 79/79 [==============================] - 7s 88ms/step - loss: 0.9288 - accuracy: 0.6688 - val_loss: 1.1686 - val_accuracy: 0.6515
# Epoch 8/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8832 - accuracy: 0.6840
# Epoch 8: val_accuracy improved from 0.65320 to 0.69400, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 90ms/step - loss: 0.8833 - accuracy: 0.6839 - val_loss: 0.9251 - val_accuracy: 0.6940
# Epoch 9/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.8294 - accuracy: 0.7055
# Epoch 9: val_accuracy improved from 0.69400 to 0.70940, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 88ms/step - loss: 0.8296 - accuracy: 0.7054 - val_loss: 0.8379 - val_accuracy: 0.7094
# Epoch 10/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7916 - accuracy: 0.7211
# Epoch 10: val_accuracy improved from 0.70940 to 0.72160, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 88ms/step - loss: 0.7916 - accuracy: 0.7212 - val_loss: 0.7971 - val_accuracy: 0.7216
# Epoch 11/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7615 - accuracy: 0.7311
# Epoch 11: val_accuracy improved from 0.72160 to 0.72930, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 92ms/step - loss: 0.7616 - accuracy: 0.7311 - val_loss: 0.7850 - val_accuracy: 0.7293
# Epoch 12/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.7273 - accuracy: 0.7436
# Epoch 12: val_accuracy did not improve from 0.72930
# 79/79 [==============================] - 7s 87ms/step - loss: 0.7273 - accuracy: 0.7436 - val_loss: 0.8498 - val_accuracy: 0.7126
# Epoch 13/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6967 - accuracy: 0.7547
# Epoch 13: val_accuracy improved from 0.72930 to 0.74470, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.6966 - accuracy: 0.7548 - val_loss: 0.7220 - val_accuracy: 0.7447
# Epoch 14/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6716 - accuracy: 0.7608
# Epoch 14: val_accuracy did not improve from 0.74470
# 79/79 [==============================] - 7s 85ms/step - loss: 0.6711 - accuracy: 0.7610 - val_loss: 0.7673 - val_accuracy: 0.7404
# Epoch 15/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6355 - accuracy: 0.7752
# Epoch 15: val_accuracy did not improve from 0.74470
# 79/79 [==============================] - 7s 89ms/step - loss: 0.6352 - accuracy: 0.7753 - val_loss: 0.7817 - val_accuracy: 0.7349
# Epoch 16/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.6211 - accuracy: 0.7799
# Epoch 16: val_accuracy improved from 0.74470 to 0.77190, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.6213 - accuracy: 0.7798 - val_loss: 0.6585 - val_accuracy: 0.7719
# Epoch 17/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5948 - accuracy: 0.7897
# Epoch 17: val_accuracy improved from 0.77190 to 0.78880, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 94ms/step - loss: 0.5945 - accuracy: 0.7898 - val_loss: 0.6218 - val_accuracy: 0.7888
# Epoch 18/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5773 - accuracy: 0.7960
# Epoch 18: val_accuracy did not improve from 0.78880
# 79/79 [==============================] - 7s 84ms/step - loss: 0.5773 - accuracy: 0.7960 - val_loss: 0.6437 - val_accuracy: 0.7806
# Epoch 19/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5580 - accuracy: 0.8021
# Epoch 19: val_accuracy did not improve from 0.78880
# 79/79 [==============================] - 7s 90ms/step - loss: 0.5578 - accuracy: 0.8022 - val_loss: 0.6290 - val_accuracy: 0.7873
# Epoch 20/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5287 - accuracy: 0.8137
# Epoch 20: val_accuracy improved from 0.78880 to 0.79240, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 90ms/step - loss: 0.5288 - accuracy: 0.8137 - val_loss: 0.6196 - val_accuracy: 0.7924
# Epoch 21/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5312 - accuracy: 0.8105
# Epoch 21: val_accuracy did not improve from 0.79240
# 79/79 [==============================] - 7s 90ms/step - loss: 0.5312 - accuracy: 0.8104 - val_loss: 0.6561 - val_accuracy: 0.7800
# Epoch 22/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.5118 - accuracy: 0.8203
# Epoch 22: val_accuracy improved from 0.79240 to 0.79470, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 92ms/step - loss: 0.5120 - accuracy: 0.8202 - val_loss: 0.6134 - val_accuracy: 0.7947
# Epoch 23/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4966 - accuracy: 0.8228
# Epoch 23: val_accuracy did not improve from 0.79470
# 79/79 [==============================] - 7s 87ms/step - loss: 0.4964 - accuracy: 0.8229 - val_loss: 0.6725 - val_accuracy: 0.7788
# Epoch 24/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4761 - accuracy: 0.8300
# Epoch 24: val_accuracy improved from 0.79470 to 0.79540, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 88ms/step - loss: 0.4757 - accuracy: 0.8301 - val_loss: 0.6070 - val_accuracy: 0.7954
# Epoch 25/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4583 - accuracy: 0.8364
# Epoch 25: val_accuracy improved from 0.79540 to 0.79600, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 85ms/step - loss: 0.4582 - accuracy: 0.8364 - val_loss: 0.6016 - val_accuracy: 0.7960
# Epoch 26/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4531 - accuracy: 0.8378
# Epoch 26: val_accuracy improved from 0.79600 to 0.80280, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.4530 - accuracy: 0.8378 - val_loss: 0.5918 - val_accuracy: 0.8028
# Epoch 27/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4371 - accuracy: 0.8431
# Epoch 27: val_accuracy did not improve from 0.80280
# 79/79 [==============================] - 7s 84ms/step - loss: 0.4372 - accuracy: 0.8430 - val_loss: 0.5951 - val_accuracy: 0.7964
# Epoch 28/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4319 - accuracy: 0.8465
# Epoch 28: val_accuracy did not improve from 0.80280
# 79/79 [==============================] - 7s 85ms/step - loss: 0.4319 - accuracy: 0.8465 - val_loss: 0.6151 - val_accuracy: 0.8008
# Epoch 29/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4311 - accuracy: 0.8485
# Epoch 29: val_accuracy improved from 0.80280 to 0.81100, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.4313 - accuracy: 0.8485 - val_loss: 0.5780 - val_accuracy: 0.8110
# Epoch 30/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4185 - accuracy: 0.8513
# Epoch 30: val_accuracy did not improve from 0.81100
# 79/79 [==============================] - 7s 85ms/step - loss: 0.4185 - accuracy: 0.8512 - val_loss: 0.5850 - val_accuracy: 0.8057
# Epoch 31/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.4105 - accuracy: 0.8536
# Epoch 31: val_accuracy did not improve from 0.81100
# 79/79 [==============================] - 7s 89ms/step - loss: 0.4104 - accuracy: 0.8537 - val_loss: 0.6571 - val_accuracy: 0.7879
# Epoch 32/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3954 - accuracy: 0.8604
# Epoch 32: val_accuracy improved from 0.81100 to 0.81570, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.3954 - accuracy: 0.8603 - val_loss: 0.5715 - val_accuracy: 0.8157
# Epoch 33/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3899 - accuracy: 0.8630
# Epoch 33: val_accuracy did not improve from 0.81570
# 79/79 [==============================] - 7s 85ms/step - loss: 0.3900 - accuracy: 0.8630 - val_loss: 0.5734 - val_accuracy: 0.8143
# Epoch 34/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3689 - accuracy: 0.8687
# Epoch 34: val_accuracy improved from 0.81570 to 0.81980, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.3688 - accuracy: 0.8688 - val_loss: 0.5685 - val_accuracy: 0.8198
# Epoch 35/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3573 - accuracy: 0.8727
# Epoch 35: val_accuracy improved from 0.81980 to 0.82110, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 87ms/step - loss: 0.3573 - accuracy: 0.8727 - val_loss: 0.5659 - val_accuracy: 0.8211
# Epoch 36/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3579 - accuracy: 0.8737
# Epoch 36: val_accuracy did not improve from 0.82110
# 79/79 [==============================] - 7s 88ms/step - loss: 0.3581 - accuracy: 0.8737 - val_loss: 0.5927 - val_accuracy: 0.8148
# Epoch 37/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3592 - accuracy: 0.8706
# Epoch 37: val_accuracy improved from 0.82110 to 0.82170, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 87ms/step - loss: 0.3591 - accuracy: 0.8706 - val_loss: 0.5565 - val_accuracy: 0.8217
# Epoch 38/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3475 - accuracy: 0.8746
# Epoch 38: val_accuracy did not improve from 0.82170
# 79/79 [==============================] - 7s 85ms/step - loss: 0.3472 - accuracy: 0.8747 - val_loss: 0.6110 - val_accuracy: 0.8111
# Epoch 39/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3304 - accuracy: 0.8811
# Epoch 39: val_accuracy improved from 0.82170 to 0.82340, saving model to /tmp/chkpoint
# 79/79 [==============================] - 7s 86ms/step - loss: 0.3307 - accuracy: 0.8810 - val_loss: 0.5761 - val_accuracy: 0.8234
# Epoch 40/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3326 - accuracy: 0.8805
# Epoch 40: val_accuracy did not improve from 0.82340
# 79/79 [==============================] - 7s 85ms/step - loss: 0.3326 - accuracy: 0.8804 - val_loss: 0.6187 - val_accuracy: 0.8114
# Epoch 41/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3360 - accuracy: 0.8811
# Epoch 41: val_accuracy did not improve from 0.82340
# 79/79 [==============================] - 7s 84ms/step - loss: 0.3361 - accuracy: 0.8810 - val_loss: 0.6473 - val_accuracy: 0.7998
# Epoch 42/300
# 78/79 [============================>.] - ETA: 0s - loss: 0.3267 - accuracy: 0.8811
# Epoch 42: val_accuracy did not improve from 0.82340
# 79/79 [==============================] - 7s 85ms/step - loss: 0.3267 - accuracy: 0.8811 - val_loss: 0.5705 - val_accuracy: 0.8226

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:04:57.368644

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 81.600

# %%
model.load_weights('/tmp/chkpoint')

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/M7. Deep Learning/Entregable 4/" # A revisar en vuestra instancia

# model.save(ruta_googledrive+'cifar10_base_model.h5')
