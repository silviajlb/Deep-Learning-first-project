# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# # Aquí iria el codigo para conectarse a Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
# prueba 1
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential()

# Primera capa de convolución
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))


# Segunda capa de convolución
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))


# Tercera capa de convolución
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        36928
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization (Batch  (None, 8, 8, 128)         512
#  Normalization)
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 128)         147584
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 500)               1024500
#
#  dropout_3 (Dropout)         (None, 500)               0
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 1510790 (5.76 MB)
# Trainable params: 1510534 (5.76 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %% [markdown]
# # Data aumentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# tranformaciones geometricas funcionan mejor que las de color

train_datagen = ImageDataGenerator( rescale=1./255,
    rotation_range = 45, horizontal_flip = True,
    width_shift_range=0.2, height_shift_range=0.2,
    shear_range=0.2)

train_generator = train_datagen.flow(
    x_train,y_train, batch_size=30)

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255)
validation_generator = validation_datagen.flow(
    x_val, y_val, batch_size=20)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_acc = EarlyStopping(monitor='val_accuracy', patience=5)

modelchk = ModelCheckpoint('/tmp/chkpoint', monitor = 'val_accuracy',
                           verbose=1, save_best_only=True, save_weights_only=True)

# %%
t = time.perf_counter()

# %%
epochs = 300
batch_size=256

history = model.fit(train_generator,
                    epochs=epochs,
                    validation_data = validation_generator,
                    batch_size = batch_size,
                    callbacks=[modelchk, callback_loss, callback_acc])
                    # steps_per_epoch=len(x_train) / 30,  # Número de pasos por época
                    # validation_steps=len(x_val) / 20  # Número de pasos de validación
# Out:
# Epoch 1/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.9791 - accuracy: 0.2571
# Epoch 1: val_accuracy improved from -inf to 0.36790, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 49s 28ms/step - loss: 1.9791 - accuracy: 0.2571 - val_loss: 1.6813 - val_accuracy: 0.3679
# Epoch 2/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.7896 - accuracy: 0.3314
# Epoch 2: val_accuracy improved from 0.36790 to 0.39830, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 38s 29ms/step - loss: 1.7896 - accuracy: 0.3314 - val_loss: 1.6029 - val_accuracy: 0.3983
# Epoch 3/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.6854 - accuracy: 0.3748
# Epoch 3: val_accuracy improved from 0.39830 to 0.45270, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 38s 29ms/step - loss: 1.6854 - accuracy: 0.3749 - val_loss: 1.4811 - val_accuracy: 0.4527
# Epoch 4/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.6031 - accuracy: 0.4136
# Epoch 4: val_accuracy did not improve from 0.45270
# 1334/1334 [==============================] - 38s 28ms/step - loss: 1.6031 - accuracy: 0.4136 - val_loss: 1.5272 - val_accuracy: 0.4424
# Epoch 5/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.5534 - accuracy: 0.4334
# Epoch 5: val_accuracy improved from 0.45270 to 0.47490, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 35s 27ms/step - loss: 1.5532 - accuracy: 0.4335 - val_loss: 1.4785 - val_accuracy: 0.4749
# Epoch 6/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.5164 - accuracy: 0.4469
# Epoch 6: val_accuracy improved from 0.47490 to 0.48740, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.5164 - accuracy: 0.4470 - val_loss: 1.4129 - val_accuracy: 0.4874
# Epoch 7/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.4808 - accuracy: 0.4615
# Epoch 7: val_accuracy improved from 0.48740 to 0.49980, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 38s 29ms/step - loss: 1.4807 - accuracy: 0.4615 - val_loss: 1.3688 - val_accuracy: 0.4998
# Epoch 8/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.4521 - accuracy: 0.4710
# Epoch 8: val_accuracy improved from 0.49980 to 0.56490, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 35s 27ms/step - loss: 1.4521 - accuracy: 0.4710 - val_loss: 1.2072 - val_accuracy: 0.5649
# Epoch 9/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.4284 - accuracy: 0.4855
# Epoch 9: val_accuracy did not improve from 0.56490
# 1334/1334 [==============================] - 37s 28ms/step - loss: 1.4284 - accuracy: 0.4854 - val_loss: 1.3147 - val_accuracy: 0.5089
# Epoch 10/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.3972 - accuracy: 0.4953
# Epoch 10: val_accuracy did not improve from 0.56490
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.3971 - accuracy: 0.4954 - val_loss: 1.3215 - val_accuracy: 0.5286
# Epoch 11/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.3768 - accuracy: 0.5041
# Epoch 11: val_accuracy did not improve from 0.56490
# 1334/1334 [==============================] - 37s 28ms/step - loss: 1.3768 - accuracy: 0.5041 - val_loss: 1.4767 - val_accuracy: 0.4794
# Epoch 12/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.3653 - accuracy: 0.5105
# Epoch 12: val_accuracy did not improve from 0.56490
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.3653 - accuracy: 0.5105 - val_loss: 1.4293 - val_accuracy: 0.4932
# Epoch 13/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.3392 - accuracy: 0.5173
# Epoch 13: val_accuracy improved from 0.56490 to 0.57570, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 37s 28ms/step - loss: 1.3389 - accuracy: 0.5174 - val_loss: 1.1793 - val_accuracy: 0.5757
# Epoch 14/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.3157 - accuracy: 0.5286
# Epoch 14: val_accuracy did not improve from 0.57570
# 1334/1334 [==============================] - 37s 28ms/step - loss: 1.3155 - accuracy: 0.5287 - val_loss: 1.4503 - val_accuracy: 0.5176
# Epoch 15/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.3035 - accuracy: 0.5339
# Epoch 15: val_accuracy did not improve from 0.57570
# 1334/1334 [==============================] - 37s 28ms/step - loss: 1.3035 - accuracy: 0.5339 - val_loss: 1.3346 - val_accuracy: 0.5256
# Epoch 16/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.2826 - accuracy: 0.5430
# Epoch 16: val_accuracy did not improve from 0.57570
# 1334/1334 [==============================] - 37s 28ms/step - loss: 1.2826 - accuracy: 0.5430 - val_loss: 1.3407 - val_accuracy: 0.5388
# Epoch 17/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.2714 - accuracy: 0.5484
# Epoch 17: val_accuracy improved from 0.57570 to 0.59150, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 37s 28ms/step - loss: 1.2713 - accuracy: 0.5484 - val_loss: 1.1346 - val_accuracy: 0.5915
# Epoch 18/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.2569 - accuracy: 0.5494
# Epoch 18: val_accuracy did not improve from 0.59150
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.2569 - accuracy: 0.5494 - val_loss: 1.3047 - val_accuracy: 0.5344
# Epoch 19/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.2427 - accuracy: 0.5561
# Epoch 19: val_accuracy did not improve from 0.59150
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.2427 - accuracy: 0.5561 - val_loss: 1.2266 - val_accuracy: 0.5742
# Epoch 20/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.2275 - accuracy: 0.5612
# Epoch 20: val_accuracy improved from 0.59150 to 0.59920, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.2275 - accuracy: 0.5612 - val_loss: 1.1142 - val_accuracy: 0.5992
# Epoch 21/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.2229 - accuracy: 0.5669
# Epoch 21: val_accuracy improved from 0.59920 to 0.60570, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.2233 - accuracy: 0.5668 - val_loss: 1.0946 - val_accuracy: 0.6057
# Epoch 22/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.2041 - accuracy: 0.5711
# Epoch 22: val_accuracy did not improve from 0.60570
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.2042 - accuracy: 0.5710 - val_loss: 1.4605 - val_accuracy: 0.5357
# Epoch 23/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.1872 - accuracy: 0.5799
# Epoch 23: val_accuracy did not improve from 0.60570
# 1334/1334 [==============================] - 35s 26ms/step - loss: 1.1871 - accuracy: 0.5801 - val_loss: 1.2024 - val_accuracy: 0.5645
# Epoch 24/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.1913 - accuracy: 0.5785
# Epoch 24: val_accuracy improved from 0.60570 to 0.60750, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 35s 26ms/step - loss: 1.1914 - accuracy: 0.5784 - val_loss: 1.1485 - val_accuracy: 0.6075
# Epoch 25/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.1744 - accuracy: 0.5849
# Epoch 25: val_accuracy improved from 0.60750 to 0.61130, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 34s 26ms/step - loss: 1.1743 - accuracy: 0.5849 - val_loss: 1.0985 - val_accuracy: 0.6113
# Epoch 26/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.1659 - accuracy: 0.5871
# Epoch 26: val_accuracy did not improve from 0.61130
# 1334/1334 [==============================] - 37s 28ms/step - loss: 1.1662 - accuracy: 0.5870 - val_loss: 1.4763 - val_accuracy: 0.5265

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:17:36.310987

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 52.150

# %%
model.load_weights('/tmp/chkpoint')

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/M7. Deep Learning/Entregable 4/" # A revisar en vuestra instancia

# model.save(ruta_googledrive+'cifar10_base_model.h5')
