# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# # Aquí iria el codigo para conectarse a Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
# prueba 1
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential()

# Primera capa de convolución
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))


# Segunda capa de convolución
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))


# Tercera capa de convolución
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))

# %%
# from keras.models import Sequential
# from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# model = Sequential()

# # Primera capa de convolución
# model.add(Conv2D(16, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
# model.add(Dropout(0.3))
# model.add(Conv2D(16, (3, 3), strides=1, activation='relu', padding='same'))
# model.add(Dropout(0.3))
# model.add(MaxPooling2D((2, 2)))


# # Segunda capa de convolución
# model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
# model.add(Dropout(0.3))
# model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
# model.add(Dropout(0.3))
# model.add(MaxPooling2D((2, 2)))


# # Tercera capa de convolución
# model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
# model.add(Dropout(0.3))
# model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
# model.add(Dropout(0.3))
# model.add(MaxPooling2D((2, 2)))


# model.add(Flatten())
# model.add(Dense(500, activation='relu'))
# model.add(Dropout(0.5))

# model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (Batch  (None, 32, 32, 32)        128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        36928
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_2 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 128)         147584
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 500)               1024500
#
#  dropout_3 (Dropout)         (None, 500)               0
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 1511174 (5.76 MB)
# Trainable params: 1510726 (5.76 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %% [markdown]
# # Data aumentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# tranformaciones geometricas funcionan mejor que las de color

train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range = 15, horizontal_flip = True,
    width_shift_range=0.12,height_shift_range=0.12)

train_generator = train_datagen.flow(
    x_train, y_train,batch_size=30)

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow(
    x_val, y_val,batch_size=20)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_acc = EarlyStopping(monitor='val_accuracy', patience=5)

modelchk = ModelCheckpoint('/tmp/chkpoint', monitor = 'val_accuracy',
                           verbose=1, save_best_only=True, save_weights_only=True)

# %%
t = time.perf_counter()

# %%
epochs = 300
batch_size=256

history = model.fit(train_generator, epochs=300, validation_data = validation_generator,
                    batch_size = 256, callbacks=[modelchk, callback_loss, callback_acc])



                    # steps_per_epoch=len(x_train) / 30,  # Número de pasos por época
                    # validation_steps=len(x_val) / 20  # Número de pasos de validación
# Out:
# Epoch 1/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.8156 - accuracy: 0.3251
# Epoch 1: val_accuracy improved from -inf to 0.39830, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 46s 28ms/step - loss: 1.8154 - accuracy: 0.3252 - val_loss: 1.6683 - val_accuracy: 0.3983
# Epoch 2/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.5039 - accuracy: 0.4496
# Epoch 2: val_accuracy improved from 0.39830 to 0.48370, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.5034 - accuracy: 0.4499 - val_loss: 1.4654 - val_accuracy: 0.4837
# Epoch 3/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.3545 - accuracy: 0.5139
# Epoch 3: val_accuracy did not improve from 0.48370
# 1334/1334 [==============================] - 38s 29ms/step - loss: 1.3545 - accuracy: 0.5139 - val_loss: 1.5119 - val_accuracy: 0.4659
# Epoch 4/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.2486 - accuracy: 0.5578
# Epoch 4: val_accuracy improved from 0.48370 to 0.58270, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.2486 - accuracy: 0.5579 - val_loss: 1.2177 - val_accuracy: 0.5827
# Epoch 5/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.1676 - accuracy: 0.5877
# Epoch 5: val_accuracy improved from 0.58270 to 0.61740, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 37s 27ms/step - loss: 1.1676 - accuracy: 0.5878 - val_loss: 1.1245 - val_accuracy: 0.6174
# Epoch 6/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.1125 - accuracy: 0.6079
# Epoch 6: val_accuracy improved from 0.61740 to 0.65870, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 37s 28ms/step - loss: 1.1124 - accuracy: 0.6079 - val_loss: 0.9895 - val_accuracy: 0.6587
# Epoch 7/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.0700 - accuracy: 0.6292
# Epoch 7: val_accuracy did not improve from 0.65870
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.0700 - accuracy: 0.6292 - val_loss: 1.3436 - val_accuracy: 0.5861
# Epoch 8/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.0209 - accuracy: 0.6423
# Epoch 8: val_accuracy did not improve from 0.65870
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.0208 - accuracy: 0.6424 - val_loss: 0.9960 - val_accuracy: 0.6559
# Epoch 9/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 0.9989 - accuracy: 0.6526
# Epoch 9: val_accuracy improved from 0.65870 to 0.66270, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 36s 27ms/step - loss: 0.9990 - accuracy: 0.6527 - val_loss: 1.0361 - val_accuracy: 0.6627
# Epoch 10/300
# 1334/1334 [==============================] - ETA: 0s - loss: 0.9636 - accuracy: 0.6679
# Epoch 10: val_accuracy improved from 0.66270 to 0.69710, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 36s 27ms/step - loss: 0.9636 - accuracy: 0.6679 - val_loss: 0.9085 - val_accuracy: 0.6971
# Epoch 11/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 0.9425 - accuracy: 0.6766
# Epoch 11: val_accuracy did not improve from 0.69710
# 1334/1334 [==============================] - 37s 28ms/step - loss: 0.9424 - accuracy: 0.6767 - val_loss: 0.9774 - val_accuracy: 0.6711
# Epoch 12/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 0.9107 - accuracy: 0.6882
# Epoch 12: val_accuracy improved from 0.69710 to 0.70260, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 36s 27ms/step - loss: 0.9106 - accuracy: 0.6883 - val_loss: 0.8656 - val_accuracy: 0.7026
# Epoch 13/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 0.8928 - accuracy: 0.6952
# Epoch 13: val_accuracy improved from 0.70260 to 0.72260, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 36s 27ms/step - loss: 0.8931 - accuracy: 0.6951 - val_loss: 0.8279 - val_accuracy: 0.7226
# Epoch 14/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 0.8656 - accuracy: 0.7057
# Epoch 14: val_accuracy did not improve from 0.72260
# 1334/1334 [==============================] - 36s 27ms/step - loss: 0.8656 - accuracy: 0.7057 - val_loss: 0.9442 - val_accuracy: 0.7127
# Epoch 15/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 0.8499 - accuracy: 0.7138
# Epoch 15: val_accuracy improved from 0.72260 to 0.75380, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 36s 27ms/step - loss: 0.8496 - accuracy: 0.7139 - val_loss: 0.7480 - val_accuracy: 0.7538
# Epoch 16/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 0.8314 - accuracy: 0.7186
# Epoch 16: val_accuracy did not improve from 0.75380
# 1334/1334 [==============================] - 36s 27ms/step - loss: 0.8317 - accuracy: 0.7185 - val_loss: 0.8272 - val_accuracy: 0.7326
# Epoch 17/300
# 1334/1334 [==============================] - ETA: 0s - loss: 0.8199 - accuracy: 0.7224
# Epoch 17: val_accuracy improved from 0.75380 to 0.75770, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 37s 27ms/step - loss: 0.8199 - accuracy: 0.7224 - val_loss: 0.7331 - val_accuracy: 0.7577
# Epoch 18/300
# 1334/1334 [==============================] - ETA: 0s - loss: 0.7925 - accuracy: 0.7333
# Epoch 18: val_accuracy did not improve from 0.75770
# 1334/1334 [==============================] - 37s 28ms/step - loss: 0.7925 - accuracy: 0.7333 - val_loss: 0.8774 - val_accuracy: 0.7154
# Epoch 19/300
# 1334/1334 [==============================] - ETA: 0s - loss: 0.7740 - accuracy: 0.7391
# Epoch 19: val_accuracy improved from 0.75770 to 0.79250, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 36s 27ms/step - loss: 0.7740 - accuracy: 0.7391 - val_loss: 0.6285 - val_accuracy: 0.7925
# Epoch 20/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 0.7735 - accuracy: 0.7418
# Epoch 20: val_accuracy did not improve from 0.79250
# 1334/1334 [==============================] - 39s 29ms/step - loss: 0.7736 - accuracy: 0.7419 - val_loss: 0.7086 - val_accuracy: 0.7588
# Epoch 21/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 0.7613 - accuracy: 0.7443
# Epoch 21: val_accuracy did not improve from 0.79250
# 1334/1334 [==============================] - 36s 27ms/step - loss: 0.7612 - accuracy: 0.7444 - val_loss: 0.6688 - val_accuracy: 0.7740
# Epoch 22/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 0.7430 - accuracy: 0.7489
# Epoch 22: val_accuracy did not improve from 0.79250
# 1334/1334 [==============================] - 39s 29ms/step - loss: 0.7426 - accuracy: 0.7491 - val_loss: 0.6551 - val_accuracy: 0.7809
# Epoch 23/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 0.7264 - accuracy: 0.7545
# Epoch 23: val_accuracy did not improve from 0.79250
# 1334/1334 [==============================] - 36s 27ms/step - loss: 0.7263 - accuracy: 0.7545 - val_loss: 0.8628 - val_accuracy: 0.7417
# Epoch 24/300
# 1334/1334 [==============================] - ETA: 0s - loss: 0.7158 - accuracy: 0.7591
# Epoch 24: val_accuracy improved from 0.79250 to 0.81590, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 37s 28ms/step - loss: 0.7158 - accuracy: 0.7591 - val_loss: 0.5564 - val_accuracy: 0.8159
# Epoch 25/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 0.7165 - accuracy: 0.7595
# Epoch 25: val_accuracy did not improve from 0.81590
# 1334/1334 [==============================] - 38s 29ms/step - loss: 0.7163 - accuracy: 0.7595 - val_loss: 0.6566 - val_accuracy: 0.7857
# Epoch 26/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.7645
# Epoch 26: val_accuracy did not improve from 0.81590
# 1334/1334 [==============================] - 37s 28ms/step - loss: 0.7062 - accuracy: 0.7645 - val_loss: 0.7801 - val_accuracy: 0.7512
# Epoch 27/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 0.6884 - accuracy: 0.7693
# Epoch 27: val_accuracy did not improve from 0.81590
# 1334/1334 [==============================] - 38s 28ms/step - loss: 0.6884 - accuracy: 0.7692 - val_loss: 0.6528 - val_accuracy: 0.7791
# Epoch 28/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 0.6776 - accuracy: 0.7726
# Epoch 28: val_accuracy did not improve from 0.81590
# 1334/1334 [==============================] - 37s 28ms/step - loss: 0.6775 - accuracy: 0.7726 - val_loss: 0.6793 - val_accuracy: 0.7769
# Epoch 29/300
# 1334/1334 [==============================] - ETA: 0s - loss: 0.6689 - accuracy: 0.7747
# Epoch 29: val_accuracy improved from 0.81590 to 0.82050, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 36s 27ms/step - loss: 0.6689 - accuracy: 0.7747 - val_loss: 0.5454 - val_accuracy: 0.8205
# Epoch 30/300
# 1334/1334 [==============================] - ETA: 0s - loss: 0.6694 - accuracy: 0.7772
# Epoch 30: val_accuracy did not improve from 0.82050
# 1334/1334 [==============================] - 44s 33ms/step - loss: 0.6694 - accuracy: 0.7772 - val_loss: 0.5952 - val_accuracy: 0.7986
# Epoch 31/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 0.6523 - accuracy: 0.7820
# Epoch 31: val_accuracy did not improve from 0.82050
# 1334/1334 [==============================] - 37s 28ms/step - loss: 0.6522 - accuracy: 0.7820 - val_loss: 0.7256 - val_accuracy: 0.7785
# Epoch 32/300
# 1334/1334 [==============================] - ETA: 0s - loss: 0.6536 - accuracy: 0.7784
# Epoch 32: val_accuracy did not improve from 0.82050
# 1334/1334 [==============================] - 36s 27ms/step - loss: 0.6536 - accuracy: 0.7784 - val_loss: 0.6374 - val_accuracy: 0.7953
# Epoch 33/300
# 1334/1334 [==============================] - ETA: 0s - loss: 0.6423 - accuracy: 0.7835
# Epoch 33: val_accuracy did not improve from 0.82050
# 1334/1334 [==============================] - 38s 28ms/step - loss: 0.6423 - accuracy: 0.7835 - val_loss: 0.7135 - val_accuracy: 0.7767
# Epoch 34/300
# 1334/1334 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.7874
# Epoch 34: val_accuracy improved from 0.82050 to 0.82950, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 37s 28ms/step - loss: 0.6400 - accuracy: 0.7874 - val_loss: 0.5121 - val_accuracy: 0.8295
# Epoch 35/300
# 1334/1334 [==============================] - ETA: 0s - loss: 0.7114 - accuracy: 0.7636
# Epoch 35: val_accuracy did not improve from 0.82950
# 1334/1334 [==============================] - 37s 27ms/step - loss: 0.7114 - accuracy: 0.7636 - val_loss: 0.6395 - val_accuracy: 0.7956
# Epoch 36/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 0.6401 - accuracy: 0.7875
# Epoch 36: val_accuracy did not improve from 0.82950
# 1334/1334 [==============================] - 37s 28ms/step - loss: 0.6400 - accuracy: 0.7875 - val_loss: 0.5682 - val_accuracy: 0.8158
# Epoch 37/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 0.6155 - accuracy: 0.7915
# Epoch 37: val_accuracy did not improve from 0.82950
# 1334/1334 [==============================] - 37s 27ms/step - loss: 0.6154 - accuracy: 0.7915 - val_loss: 0.5917 - val_accuracy: 0.8088
# Epoch 38/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 0.6160 - accuracy: 0.7977
# Epoch 38: val_accuracy did not improve from 0.82950
# 1334/1334 [==============================] - 37s 28ms/step - loss: 0.6159 - accuracy: 0.7977 - val_loss: 0.5558 - val_accuracy: 0.8223
# Epoch 39/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 0.6039 - accuracy: 0.8001
# Epoch 39: val_accuracy did not improve from 0.82950
# 1334/1334 [==============================] - 37s 27ms/step - loss: 0.6039 - accuracy: 0.8000 - val_loss: 0.5563 - val_accuracy: 0.8211

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:24:29.845385

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 82.250

# %%
model.load_weights('/tmp/chkpoint')

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/M7. Deep Learning/Entregable 4/" # A revisar en vuestra instancia

# model.save(ruta_googledrive+'cifar10_base_model.h5')
