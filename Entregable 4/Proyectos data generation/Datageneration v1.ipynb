# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# # Aquí iria el codigo para conectarse a Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
# prueba 1
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential()
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 32)        9248
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 64)        36928
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization (Batch  (None, 8, 8, 128)         512
#  Normalization)
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 128)         147584
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_4 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 500)               1024500
#
#  dropout_5 (Dropout)         (None, 500)               0
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 1510790 (5.76 MB)
# Trainable params: 1510534 (5.76 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %% [markdown]
# # Data aumentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# tranformaciones geometricas funcionan mejor que las de color

train_datagen = ImageDataGenerator(
    rescale=1./255, rotation_range = 15, horizontal_flip = True,
    width_shift_range=0.12, height_shift_range=0.12)

train_generator = train_datagen.flow(
    x_train, y_train, batch_size=30)

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255)
validation_generator = validation_datagen.flow(
    x_val,
    y_val,
    batch_size=20)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_acc = EarlyStopping(monitor='val_accuracy', patience=5)

modelchk = ModelCheckpoint('/tmp/chkpoint', monitor = 'val_accuracy',
                           verbose=1, save_best_only=True, save_weights_only=True)

# %%
t = time.perf_counter()

# %%
epochs = 300
batch_size=256

history = model.fit(train_generator,
                    epochs=epochs,
                    validation_data = validation_generator,
                    batch_size = batch_size,
                    callbacks=[modelchk, callback_loss, callback_acc])
                    steps_per_epoch=len(x_train) / 30,  # Número de pasos por época
                    validation_steps=len(x_val) / 20  # Número de pasos de validación
# Out:
# Epoch 1/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.8373 - accuracy: 0.3023
# Epoch 1: val_accuracy improved from -inf to 0.39730, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 48s 29ms/step - loss: 1.8372 - accuracy: 0.3023 - val_loss: 1.6889 - val_accuracy: 0.3973
# Epoch 2/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.5740 - accuracy: 0.4203
# Epoch 2: val_accuracy improved from 0.39730 to 0.41730, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.5743 - accuracy: 0.4202 - val_loss: 1.6510 - val_accuracy: 0.4173
# Epoch 3/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.4674 - accuracy: 0.4683
# Epoch 3: val_accuracy improved from 0.41730 to 0.50990, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 34s 26ms/step - loss: 1.4674 - accuracy: 0.4683 - val_loss: 1.3871 - val_accuracy: 0.5099
# Epoch 4/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.3885 - accuracy: 0.4987
# Epoch 4: val_accuracy did not improve from 0.50990
# 1334/1334 [==============================] - 33s 25ms/step - loss: 1.3885 - accuracy: 0.4987 - val_loss: 1.5869 - val_accuracy: 0.4702
# Epoch 5/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.3244 - accuracy: 0.5271
# Epoch 5: val_accuracy improved from 0.50990 to 0.59730, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 33s 25ms/step - loss: 1.3245 - accuracy: 0.5270 - val_loss: 1.1113 - val_accuracy: 0.5973
# Epoch 6/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.2822 - accuracy: 0.5418
# Epoch 6: val_accuracy improved from 0.59730 to 0.60210, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 34s 25ms/step - loss: 1.2819 - accuracy: 0.5418 - val_loss: 1.1057 - val_accuracy: 0.6021
# Epoch 7/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.2376 - accuracy: 0.5609
# Epoch 7: val_accuracy did not improve from 0.60210
# 1334/1334 [==============================] - 32s 24ms/step - loss: 1.2377 - accuracy: 0.5609 - val_loss: 1.1953 - val_accuracy: 0.5883
# Epoch 8/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.1952 - accuracy: 0.5731
# Epoch 8: val_accuracy improved from 0.60210 to 0.62520, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 34s 26ms/step - loss: 1.1951 - accuracy: 0.5731 - val_loss: 1.0535 - val_accuracy: 0.6252
# Epoch 9/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.1606 - accuracy: 0.5858
# Epoch 9: val_accuracy did not improve from 0.62520
# 1334/1334 [==============================] - 35s 26ms/step - loss: 1.1607 - accuracy: 0.5858 - val_loss: 1.3178 - val_accuracy: 0.5545
# Epoch 10/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.1362 - accuracy: 0.5985
# Epoch 10: val_accuracy did not improve from 0.62520
# 1334/1334 [==============================] - 33s 25ms/step - loss: 1.1363 - accuracy: 0.5985 - val_loss: 1.1124 - val_accuracy: 0.6104
# Epoch 11/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.1137 - accuracy: 0.6072
# Epoch 11: val_accuracy did not improve from 0.62520
# 1334/1334 [==============================] - 33s 25ms/step - loss: 1.1137 - accuracy: 0.6072 - val_loss: 1.1198 - val_accuracy: 0.6206
# Epoch 12/300
# 1334/1334 [==============================] - ETA: 0s - loss: 1.0828 - accuracy: 0.6177
# Epoch 12: val_accuracy improved from 0.62520 to 0.65590, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 33s 25ms/step - loss: 1.0828 - accuracy: 0.6177 - val_loss: 0.9860 - val_accuracy: 0.6559
# Epoch 13/300
# 1333/1334 [============================>.] - ETA: 0s - loss: 1.0590 - accuracy: 0.6266
# Epoch 13: val_accuracy improved from 0.65590 to 0.67790, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 34s 25ms/step - loss: 1.0592 - accuracy: 0.6266 - val_loss: 0.9103 - val_accuracy: 0.6779
# Epoch 14/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.0522 - accuracy: 0.6311
# Epoch 14: val_accuracy did not improve from 0.67790
# 1334/1334 [==============================] - 33s 25ms/step - loss: 1.0522 - accuracy: 0.6310 - val_loss: 1.0513 - val_accuracy: 0.6417
# Epoch 15/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.0181 - accuracy: 0.6445
# Epoch 15: val_accuracy did not improve from 0.67790
# 1334/1334 [==============================] - 33s 25ms/step - loss: 1.0180 - accuracy: 0.6446 - val_loss: 0.9961 - val_accuracy: 0.6536
# Epoch 16/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 1.0023 - accuracy: 0.6507
# Epoch 16: val_accuracy did not improve from 0.67790
# 1334/1334 [==============================] - 36s 27ms/step - loss: 1.0022 - accuracy: 0.6506 - val_loss: 0.9902 - val_accuracy: 0.6591
# Epoch 17/300
# 1334/1334 [==============================] - ETA: 0s - loss: 0.9912 - accuracy: 0.6533
# Epoch 17: val_accuracy did not improve from 0.67790
# 1334/1334 [==============================] - 34s 25ms/step - loss: 0.9912 - accuracy: 0.6533 - val_loss: 0.9834 - val_accuracy: 0.6601
# Epoch 18/300
# 1332/1334 [============================>.] - ETA: 0s - loss: 0.9679 - accuracy: 0.6618
# Epoch 18: val_accuracy improved from 0.67790 to 0.68550, saving model to /tmp/chkpoint
# 1334/1334 [==============================] - 33s 25ms/step - loss: 0.9677 - accuracy: 0.6619 - val_loss: 0.9560 - val_accuracy: 0.6855

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:11:16.236478

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 68.750

# %%
model.load_weights('/tmp/chkpoint')

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/M7. Deep Learning/Entregable 4/" # A revisar en vuestra instancia

# model.save(ruta_googledrive+'cifar10_base_model.h5')
